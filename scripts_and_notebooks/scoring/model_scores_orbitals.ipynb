# %%
import pickle
import pandas as pd
import numpy as np
import tensorflow as tf
from pathlib import Path
from dataclasses import dataclass, field
from mbeml.constants import LigandFeatures, TargetProperty, unique_cores
from mbeml.featurization import data_prep
from mbeml.metrics import (
    mean_absolute_error,
    r2_score,
    mean_negative_log_likelihood,
    max_absolute_error,
    std_absolute_error,
)
# Out:
# 2024-06-24 17:54:07.673554: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-24 17:54:07.675647: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-24 17:54:07.707452: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-24 17:54:07.707996: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-24 17:54:08.188003: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data_dir = Path("../../data/")

data_sets = {
    "train": pd.read_csv(data_dir / "training_data.csv"),
    "validation": pd.read_csv(data_dir / "validation_data.csv"),
    "composition_test": pd.read_csv(data_dir / "composition_test_data.csv"),
    "ligand_test": pd.read_csv(data_dir / "ligand_test_data.csv"),
}

model_dir = Path("../../models/")

# %%
@dataclass
class Experiment:
    name: str
    features: LigandFeatures
    target: TargetProperty = TargetProperty.ORBITALS
    is_nn: bool = False
    predictions: dict = field(
        default_factory=lambda: {
            key: np.zeros([len(df), 4]) for key, df in data_sets.items()
        }
    )
    uncertainties: dict = field(
        default_factory=lambda: {
            key: np.zeros([len(df), 4]) for key, df in data_sets.items()
        }
    )

# %%
experiments = [
    Experiment(name="krr_standard_racs", features=LigandFeatures.STANDARD_RACS),
    Experiment(name="krr_two_body", features=LigandFeatures.LIGAND_RACS),
    Experiment(name="krr_three_body", features=LigandFeatures.LIGAND_RACS),
    Experiment(
        name="nn_standard_racs", features=LigandFeatures.STANDARD_RACS, is_nn=True
    ),
    Experiment(name="nn_two_body", features=LigandFeatures.LIGAND_RACS, is_nn=True),
    Experiment(name="nn_three_body", features=LigandFeatures.LIGAND_RACS, is_nn=True),
]

# %%
for experiment in experiments:
    for df_name, data_set in data_sets.items():
        X, y = data_prep(
            data_set, experiment.features, experiment.target, experiment.is_nn
        )
        if experiment.is_nn:
            model = tf.keras.models.load_model(
                model_dir / experiment.target.name.lower() / experiment.name
            )
            y_mean, y_std = model.predict(X, verbose=0)
        else:
            with open(
                model_dir / experiment.target.name.lower() / f"{experiment.name}.pkl",
                "rb",
            ) as fin:
                model = pickle.load(fin)
            y_mean, y_std = model.predict(X, return_std=True)
        experiment.predictions[df_name] = y_mean
        experiment.uncertainties[df_name] = y_std
# Out:
# 2024-06-24 17:54:53.180448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.182623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.212839: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.214671: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.242802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.244658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.275980: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.277989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.307495: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.309547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.338756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.341031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.370545: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.372931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.401895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.404111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.434638: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.436619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.464397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:53.466149: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.493191: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.516080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.539931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.563760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.586069: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.613805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.636288: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.658826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.680673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:53.702410: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.364940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.367387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.397578: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.399520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.430315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.432391: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.469296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.473056: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.506321: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.508675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.535781: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.537995: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.566125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.568640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.601754: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.603871: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.631071: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.632954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.660295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:54:57.662217: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.688066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.711612: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.736609: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.768548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.795163: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.819211: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.844064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.867829: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.892979: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:54:57.916970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.031774: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.033915: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.061351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.063117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.088668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.090579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.115303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.117142: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.146161: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.147970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.173453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.175377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.199877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.201810: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.228104: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.230024: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.258976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.261193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.293226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:02.295286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.320983: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.342518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.363576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.384703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.406572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.428615: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.450713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.480041: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.502976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:02.526231: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.386936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.389623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.419778: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.421862: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.447876: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.449750: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.477158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.479198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.505893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.507965: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.534931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.536884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.568148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.570069: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.599806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.602237: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.631491: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.633831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.663721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:06.666000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.697731: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.726325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.749694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.775085: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.799644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.827176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.852658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.877436: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.902667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:06.936263: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:16.751386: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:16.753641: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:16.830592: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:16.832929: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:16.909698: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:16.911604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:16.990536: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:16.992775: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.072060: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:17.073887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.148840: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:17.150770: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.229880: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:17.232248: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.310419: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:17.312267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.386298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:17.388224: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.469798: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:17.471957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.553645: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.616595: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.675986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:17.737520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# ...
# 2024-06-24 17:55:42.740166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:42.742255: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:42.815046: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:42.817044: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:42.896365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:42.898152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:42.976487: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:42.978845: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.056742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.117857: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.177234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.238837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.298358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.364948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.428928: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.488773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.551707: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:43.610773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:54.401222: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:54.403259: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:54.483285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:54.485052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:54.558915: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:54.560847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:54.640997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:54.643087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:54.717902: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:54.719730: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:54.797760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:54.799676: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:54.874989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:54.877149: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:54.953579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:54.955713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.046548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:55.049619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.138222: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,7]
# 	 [[{{node inputs}}]]
# 2024-06-24 17:55:55.141175: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.231853: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.294816: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.356171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.418677: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.490901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.553240: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.619819: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.692420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.762492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]
# 2024-06-24 17:55:55.832557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype float and shape [?,7]
# 	 [[{{node Placeholder}}]]

# %%
def evaluate_metric(metric, requires_uncertainty=False, transformation=None):
    if transformation is None:
        transformation = lambda x: x
    results = {}
    for experiment in experiments:
        result_row = {}
        for key, data_set in data_sets.items():
            if requires_uncertainty:
                result_row[key] = metric(
                    transformation(data_set[experiment.target.full_name()].values),
                    transformation(experiment.predictions[key]),
                    transformation(experiment.uncertainties[key]),
                )
            else:
                result_row[key] = metric(
                    transformation(data_set[experiment.target.full_name()].values),
                    transformation(experiment.predictions[key]),
                )
        results[experiment.name] = result_row
    return pd.DataFrame.from_dict(results, orient="index")

# %%
def metal_dependence(
    key: str,
    metric=mean_absolute_error,
    requires_uncertainty=False,
    transformation=None,
):
    if transformation is None:
        transformation = lambda x: x
    results = {}
    data_set = data_sets[key]
    for experiment in experiments:
        result_row = {}
        for core in unique_cores:
            mask = (data_set[["metal", "ox"]] == [core[:2], int(core[-1])]).all(axis=1)
            if requires_uncertainty:
                result_row[core] = metric(
                    transformation(
                        data_set[mask][experiment.target.full_name()].values
                    ),
                    transformation(experiment.predictions[key][mask]),
                    transformation(experiment.uncertainties[key][mask]),
                )
            else:
                result_row[core] = metric(
                    transformation(
                        data_set[mask][experiment.target.full_name()].values
                    ),
                    transformation(experiment.predictions[key][mask]),
                )
        if requires_uncertainty:
            mask = data_set["ox"] == 2
            result_row["ox2"] = metric(
                    transformation(
                        data_set[mask][experiment.target.full_name()].values
                    ),
                    transformation(experiment.predictions[key][mask]),
                    transformation(experiment.uncertainties[key][mask]),
                )
            mask = data_set["ox"] == 3
            result_row["ox3"] = metric(
                    transformation(
                        data_set[mask][experiment.target.full_name()].values
                    ),
                    transformation(experiment.predictions[key][mask]),
                    transformation(experiment.uncertainties[key][mask]),
                )
        else:
            mask = data_set["ox"] == 2
            result_row["ox2"] = metric(
                    transformation(
                        data_set[mask][experiment.target.full_name()].values
                    ),
                    transformation(experiment.predictions[key][mask]),
                )
            mask = data_set["ox"] == 3
            result_row["ox3"] = metric(
                    transformation(
                        data_set[mask][experiment.target.full_name()].values
                    ),
                    transformation(experiment.predictions[key][mask]),
                )
        if requires_uncertainty:
            result_row["all"] = metric(
                transformation(data_set[experiment.target.full_name()].values),
                transformation(experiment.predictions[key]),
                transformation(experiment.uncertainties[key]),
            )
        else:
            result_row["all"] = metric(
                transformation(data_set[experiment.target.full_name()].values),
                transformation(experiment.predictions[key]),
            )
        results[experiment.name] = result_row
    return pd.DataFrame.from_dict(results, orient="index")

# %%
test_ligands = [
    "4H-pyran",
    "[OH]-[CH]=[CH]-[OH]",
    "bifuran",
    "pyridine-N-oxide",
    "acrylamide",
    "dmf",
    "thiophene",
    "thiane",
    "4H-thiopyran",
    "oxazoline",
    "thioazole",
    "[NH]=[CH]-[OH]",
    "[PH]=[CH]-[OH]",
    "[NH2]-[NH]-[NH]-[NH2]",
    "1H-tetrazole",
    "1H-triazole",
    "thioformaldehyde",
    "[NH2]-[O]-[O]-[NH2]",
    "bipyrimidine",
    "[PH2]-[CH2]-[OH]",
    "[PH2]-[NH]-[NH]-[PH2]",
]


def ligand_dependence(
    metric,
    requires_uncertainty=False,
    transformation=None,
):
    if transformation is None:
        transformation = lambda x: x
    results = {}
    key = "ligand_test"
    data_set = data_sets[key]
    for lig in test_ligands:
        result_row = {}
        mask = data_set["name"].str.contains(lig, regex=False)
        result_row["count"] = np.count_nonzero(mask)
        for experiment in experiments:
            if requires_uncertainty:
                result_row[experiment.name] = metric(
                    transformation(
                        data_set[mask][experiment.target.full_name()].values
                    ),
                    transformation(experiment.predictions[key][mask]),
                    transformation(experiment.uncertainties[key][mask]),
                )
            else:
                result_row[experiment.name] = metric(
                    transformation(
                        data_set[mask][experiment.target.full_name()].values
                    ),
                    transformation(experiment.predictions[key][mask]),
                )
        results[lig] = result_row
    return pd.DataFrame.from_dict(results, orient="index")

# %%
TargetProperty.ORBITALS.full_name()
# Out:
# ['energetic_homo_ls_eV',
#  'energetic_homo_hs_eV',
#  'energetic_lumo_ls_eV',
#  'energetic_lumo_hs_eV']

# %%
def homo_ls(x):
    return x[:, :1]


def homo_hs(x):
    return x[:, 1:2]


def homo_both(x):
    return x[:, :2]


def lumo_both(x):
    return x[:, 2:]


def gap_both(x):
    return x[:, 2:] - x[:, :2]

# %%
evaluate_metric(mean_absolute_error).round(2)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   0.13        0.43              0.52         0.99
# krr_two_body        0.33        0.40              0.30         1.23
# krr_three_body      0.17        0.36              0.23         1.06
# nn_standard_racs    0.29        0.38              0.52         0.83
# nn_two_body         0.35        0.38              0.35         0.96
# nn_three_body       0.28        0.34              0.61         0.88

# %%
evaluate_metric(r2_score).round(2)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   1.00        0.98              0.96         0.75
# krr_two_body        0.99        0.98              0.99         0.63
# krr_three_body      1.00        0.98              0.99         0.72
# nn_standard_racs    0.99        0.98              0.96         0.82
# nn_two_body         0.99        0.98              0.98         0.77
# nn_three_body       0.99        0.98              0.94         0.81

# %% [markdown]
# # HOMO

# %%
evaluate_metric(mean_absolute_error, transformation=homo_both).round(2)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   0.15        0.37              0.58         1.03
# krr_two_body        0.41        0.44              0.28         1.27
# krr_three_body      0.22        0.40              0.23         1.12
# nn_standard_racs    0.29        0.34              0.56         0.96
# nn_two_body         0.43        0.43              0.30         1.05
# nn_three_body       0.32        0.38              0.79         0.97

# %%
evaluate_metric(r2_score, transformation=homo_both).round(3)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs  0.998       0.984             0.943        0.698
# krr_two_body       0.984       0.974             0.986        0.569
# krr_three_body     0.995       0.978             0.990        0.670
# nn_standard_racs   0.993       0.987             0.952        0.756
# nn_two_body        0.984       0.975             0.986        0.696
# nn_three_body      0.992       0.981             0.904        0.769

# %%
evaluate_metric(std_absolute_error, transformation=homo_both).round(2)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   0.16        0.34              0.47         0.86
# krr_two_body        0.43        0.45              0.24         0.99
# krr_three_body      0.26        0.42              0.21         0.86
# nn_standard_racs    0.26        0.30              0.37         0.74
# nn_two_body         0.42        0.44              0.22         0.85
# nn_three_body       0.28        0.38              0.54         0.67

# %%
evaluate_metric(max_absolute_error, transformation=homo_both).round(2)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   1.84        2.03              2.28         3.91
# krr_two_body        3.18        3.02              1.39         4.71
# krr_three_body      2.51        3.25              1.27         4.25
# nn_standard_racs    2.63        2.28              2.01         3.22
# nn_two_body         3.28        2.98              1.22         4.15
# nn_three_body       1.96        4.50              2.34         3.12

# %%
evaluate_metric(mean_absolute_error, transformation=homo_ls).round(2)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   0.15        0.38              0.58         1.07
# krr_two_body        0.41        0.44              0.29         1.28
# krr_three_body      0.22        0.40              0.23         1.10
# nn_standard_racs    0.29        0.35              0.50         0.94
# nn_two_body         0.43        0.42              0.28         1.08
# nn_three_body       0.31        0.39              0.72         0.99

# %%
evaluate_metric(mean_absolute_error, transformation=homo_hs).round(2)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   0.15        0.37              0.58         1.00
# krr_two_body        0.41        0.45              0.27         1.26
# krr_three_body      0.22        0.41              0.22         1.14
# nn_standard_racs    0.29        0.34              0.63         0.97
# nn_two_body         0.43        0.44              0.32         1.02
# nn_three_body       0.33        0.37              0.86         0.96

# %%
metal_dependence(
    "composition_test", mean_absolute_error, transformation=homo_both
).round(2)
# Out:
#                     cr3   cr2   mn3   mn2   fe3   fe2   co3   co2   ox2   ox3  \
# krr_standard_racs  0.59  0.49  0.52  0.56  0.60  0.58  0.51  0.76  0.60  0.56
# krr_two_body       0.34  0.19  0.38  0.21  0.22  0.25  0.44  0.21  0.22  0.35
# krr_three_body     0.26  0.22  0.29  0.17  0.17  0.16  0.38  0.19  0.18  0.27
# nn_standard_racs   0.69  0.34  0.58  0.52  0.72  0.45  0.52  0.66  0.49  0.63
# nn_two_body        0.31  0.33  0.35  0.25  0.27  0.23  0.42  0.22  0.26  0.34
# nn_three_body      1.09  0.33  0.74  0.65  1.10  0.58  0.98  0.83  0.60  0.98
#
#                     all
# krr_standard_racs  0.58
# krr_two_body       0.28
# krr_three_body     0.23
# nn_standard_racs   0.56
# nn_two_body        0.30
# nn_three_body      0.79

# %%
metal_dependence("composition_test", r2_score, transformation=homo_both).round(2)
# Out:
#                     cr3    cr2   mn3    mn2   fe3    fe2   co3    co2   ox2  \
# krr_standard_racs -2.38 -17.84 -1.88 -17.39 -1.92 -34.58  0.06 -14.85 -0.34
# krr_two_body       0.23  -0.86 -0.18  -1.19  0.49  -8.17  0.22  -0.01  0.84
# krr_three_body     0.53  -1.06  0.30  -0.33  0.70  -1.87  0.37   0.19  0.89
# nn_standard_racs  -2.11  -5.96 -2.19 -12.75 -2.79 -14.96  0.10  -8.50  0.26
# nn_two_body        0.45  -5.12 -0.08  -2.23  0.44  -6.85  0.41  -0.12  0.77
# nn_three_body     -6.58  -5.30 -3.89 -22.67 -7.56 -30.14 -1.66 -14.75 -0.18
#
#                     ox3   all
# krr_standard_racs -0.54  0.94
# krr_two_body       0.37  0.99
# krr_three_body     0.55  0.99
# nn_standard_racs  -0.71  0.95
# nn_two_body        0.47  0.99
# nn_three_body     -2.89  0.90

# %%
metal_dependence("ligand_test", mean_absolute_error, transformation=homo_both).round(2)
# Out:
#                     cr3   cr2   mn3   mn2   fe3   fe2   co3   co2   ox2   ox3  \
# krr_standard_racs  1.27  0.76  1.35  0.81  1.22  0.84  1.67  0.95  0.85  1.34
# krr_two_body       1.66  0.96  1.43  1.03  1.52  1.07  1.83  1.16  1.06  1.60
# krr_three_body     1.39  0.80  1.36  0.93  1.28  0.92  1.65  1.10  0.94  1.39
# nn_standard_racs   1.20  0.70  1.42  0.74  1.07  0.81  1.37  0.88  0.79  1.23
# nn_two_body        1.49  0.82  1.24  0.81  1.20  0.85  1.48  0.93  0.86  1.36
# nn_three_body      1.17  0.78  1.23  0.84  0.97  0.88  1.13  0.99  0.88  1.12
#
#                     all
# krr_standard_racs  1.03
# krr_two_body       1.27
# krr_three_body     1.12
# nn_standard_racs   0.96
# nn_two_body        1.05
# nn_three_body      0.97

# %%
metal_dependence("ligand_test", r2_score, transformation=homo_both).round(2)
# Out:
#                     cr3   cr2   mn3   mn2   fe3   fe2   co3   co2   ox2   ox3  \
# krr_standard_racs  0.11  0.36 -1.82 -0.01  0.12  0.16 -5.36 -0.46  0.13 -0.26
# krr_two_body      -0.43  0.06 -2.00 -0.35 -0.28 -0.30 -8.18 -0.97 -0.24 -0.81
# krr_three_body     0.00  0.36 -1.84 -0.11  0.12  0.02 -6.20 -0.72  0.02 -0.35
# nn_standard_racs   0.30  0.47 -1.81  0.27  0.32  0.33 -3.99 -0.14  0.32 -0.04
# nn_two_body       -0.06  0.36 -1.55  0.09  0.18  0.18 -5.73 -0.34  0.18 -0.32
# nn_three_body      0.38  0.33 -1.23  0.05  0.48  0.19 -1.49 -0.39  0.15  0.22
#
#                     all
# krr_standard_racs  0.70
# krr_two_body       0.57
# krr_three_body     0.67
# nn_standard_racs   0.76
# nn_two_body        0.70
# nn_three_body      0.77

# %%
metal_dependence(
    "ligand_test",
    mean_negative_log_likelihood,
    requires_uncertainty=True,
    transformation=homo_both,
).round(2)
# Out:
#                       cr3    cr2     mn3    mn2     fe3    fe2     co3    co2  \
# krr_standard_racs    3.04   2.88    2.96   2.97    3.02   2.94    3.13   2.96
# krr_two_body         2.45   2.20    2.18   2.25    2.33   2.24    2.39   2.28
# krr_three_body       2.69   2.52    2.48   2.58    2.62   2.57    2.63   2.59
# nn_standard_racs   107.52  76.59  126.79  57.84  159.99  65.58  153.38  79.72
# nn_two_body         30.46  12.73   34.69  12.60   15.61  18.83   43.19  21.62
# nn_three_body       44.76  15.15   70.05  19.48   37.40  18.70   17.31  15.39
#
#                      ox2     ox3    all
# krr_standard_racs   2.93    3.03   2.97
# krr_two_body        2.24    2.36   2.29
# krr_three_body      2.57    2.62   2.59
# nn_standard_racs   70.14  133.54  94.60
# nn_two_body        16.73   29.07  21.49
# nn_three_body      17.17   42.82  27.07

# %%
ligand_dependence(mean_absolute_error, transformation=homo_both).round(2)
# Out:
#                        count  krr_standard_racs  krr_two_body  krr_three_body  \
# 4H-pyran                   3               0.32          0.69            0.39
# [OH]-[CH]=[CH]-[OH]        4               1.63          2.22            2.08
# bifuran                    4               0.33          1.57            1.38
# pyridine-N-oxide           7               0.88          1.65            1.81
# acrylamide                 7               0.34          0.70            0.83
# dmf                        8               2.45          0.43            0.09
# thiophene                  5               0.73          0.45            0.13
# thiane                     5               1.59          1.26            1.10
# 4H-thiopyran               5               0.37          0.56            0.92
# oxazoline                  7               2.37          2.98            2.86
# thioazole                  7               1.17          1.64            1.80
# [NH]=[CH]-[OH]             6               0.31          1.69            1.35
# [PH]=[CH]-[OH]             6               1.08          2.88            1.99
# [NH2]-[NH]-[NH]-[NH2]      5               0.75          0.39            0.66
# 1H-tetrazole               8               2.34          1.17            1.18
# 1H-triazole                7               0.89          0.64            0.53
# thioformaldehyde           6               0.46          0.81            0.71
# [NH2]-[O]-[O]-[NH2]        6               1.09          0.26            0.28
# bipyrimidine               8               0.37          1.14            0.98
# [PH2]-[CH2]-[OH]           7               0.54          2.68            1.57
# [PH2]-[NH]-[NH]-[PH2]      6               0.51          0.50            0.50
#
#                        nn_standard_racs  nn_two_body  nn_three_body
# 4H-pyran                           1.12         0.56           1.49
# [OH]-[CH]=[CH]-[OH]                1.40         1.95           1.16
# bifuran                            0.95         0.64           1.15
# pyridine-N-oxide                   1.84         1.55           2.55
# acrylamide                         0.26         0.15           0.73
# dmf                                1.56         0.82           0.80
# thiophene                          0.12         0.39           0.16
# thiane                             0.76         0.90           0.47
# 4H-thiopyran                       1.65         1.14           1.56
# oxazoline                          1.87         2.77           2.06
# thioazole                          1.34         1.72           0.82
# [NH]=[CH]-[OH]                     0.63         1.55           1.01
# [PH]=[CH]-[OH]                     0.34         2.24           1.20
# [NH2]-[NH]-[NH]-[NH2]              0.36         0.94           0.42
# 1H-tetrazole                       2.03         1.12           0.99
# 1H-triazole                        0.60         0.51           0.94
# thioformaldehyde                   0.54         0.46           0.44
# [NH2]-[O]-[O]-[NH2]                0.61         0.25           1.02
# bipyrimidine                       0.50         0.25           0.42
# [PH2]-[CH2]-[OH]                   0.52         1.24           0.42
# [PH2]-[NH]-[NH]-[PH2]              0.65         0.71           0.69

# %%
ligand_dependence(std_absolute_error, transformation=homo_both).round(2)
# Out:
#                        count  krr_standard_racs  krr_two_body  krr_three_body  \
# 4H-pyran                   3               0.23          0.26            0.31
# [OH]-[CH]=[CH]-[OH]        4               0.55          0.44            0.37
# bifuran                    4               0.20          0.20            0.32
# pyridine-N-oxide           7               0.33          0.36            0.35
# acrylamide                 7               0.17          0.22            0.18
# dmf                        8               0.30          0.30            0.07
# thiophene                  5               0.16          0.18            0.12
# thiane                     5               1.00          0.88            0.63
# 4H-thiopyran               5               0.21          0.42            0.34
# oxazoline                  7               0.30          0.84            0.88
# thioazole                  7               0.39          0.57            0.58
# [NH]=[CH]-[OH]             6               0.27          0.34            0.40
# [PH]=[CH]-[OH]             6               0.39          0.71            0.56
# [NH2]-[NH]-[NH]-[NH2]      5               0.37          0.42            0.28
# 1H-tetrazole               8               1.08          0.84            0.77
# 1H-triazole                7               0.52          0.40            0.36
# thioformaldehyde           6               0.28          0.63            0.46
# [NH2]-[O]-[O]-[NH2]        6               0.34          0.14            0.21
# bipyrimidine               8               0.23          0.29            0.38
# [PH2]-[CH2]-[OH]           7               0.31          0.87            0.71
# [PH2]-[NH]-[NH]-[PH2]      6               0.41          0.37            0.38
#
#                        nn_standard_racs  nn_two_body  nn_three_body
# 4H-pyran                           0.23         0.18           0.30
# [OH]-[CH]=[CH]-[OH]                0.41         0.52           0.59
# bifuran                            0.21         0.17           0.31
# pyridine-N-oxide                   0.21         0.16           0.33
# acrylamide                         0.16         0.13           0.20
# dmf                                0.24         0.19           0.27
# thiophene                          0.16         0.24           0.12
# thiane                             0.52         0.85           0.25
# 4H-thiopyran                       0.19         0.29           0.23
# oxazoline                          0.63         0.84           0.27
# thioazole                          0.68         0.69           0.18
# [NH]=[CH]-[OH]                     0.41         0.42           0.41
# [PH]=[CH]-[OH]                     0.16         0.46           0.21
# [NH2]-[NH]-[NH]-[NH2]              0.25         0.55           0.53
# 1H-tetrazole                       1.04         0.74           0.56
# 1H-triazole                        0.28         0.46           0.29
# thioformaldehyde                   0.29         0.23           0.24
# [NH2]-[O]-[O]-[NH2]                0.14         0.13           0.23
# bipyrimidine                       0.28         0.18           0.22
# [PH2]-[CH2]-[OH]                   0.28         0.65           0.29
# [PH2]-[NH]-[NH]-[PH2]              0.47         0.60           0.57

# %% [markdown]
# # LUMO

# %%
evaluate_metric(mean_absolute_error, transformation=lumo_both).round(
    2
)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   0.11        0.48              0.47         0.94
# krr_two_body        0.25        0.36              0.31         1.19
# krr_three_body      0.12        0.32              0.22         1.01
# nn_standard_racs    0.29        0.42              0.49         0.71
# nn_two_body         0.27        0.32              0.40         0.88
# nn_three_body       0.25        0.31              0.44         0.80

# %%
evaluate_metric(r2_score, transformation=lumo_both).round(2)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   1.00        0.97              0.97         0.81
# krr_two_body        0.99        0.98              0.99         0.68
# krr_three_body      1.00        0.99              0.99         0.78
# nn_standard_racs    0.99        0.98              0.97         0.89
# nn_two_body         0.99        0.99              0.98         0.84
# nn_three_body       0.99        0.99              0.98         0.86

# %%
metal_dependence("ligand_test", mean_absolute_error, transformation=lumo_both).round(2)
# Out:
#                     cr3   cr2   mn3   mn2   fe3   fe2   co3   co2   ox2   ox3  \
# krr_standard_racs  0.99  0.76  1.33  0.86  0.90  0.88  1.44  0.85  0.84  1.10
# krr_two_body       1.34  1.05  1.51  1.01  1.37  1.10  1.47  1.09  1.06  1.40
# krr_three_body     1.15  0.82  1.35  0.88  1.18  0.90  1.18  0.92  0.88  1.20
# nn_standard_racs   0.76  0.57  1.16  0.60  0.88  0.58  1.08  0.56  0.58  0.92
# nn_two_body        0.98  0.81  1.29  0.75  1.01  0.75  1.07  0.76  0.77  1.06
# nn_three_body      0.86  0.65  1.19  0.70  0.93  0.66  0.99  0.77  0.70  0.96
#
#                     all
# krr_standard_racs  0.94
# krr_two_body       1.19
# krr_three_body     1.01
# nn_standard_racs   0.71
# nn_two_body        0.88
# nn_three_body      0.80

# %% [markdown]
# # GAP

# %%
def count_negative_gaps():
    transformation = gap_both
    results = {}
    for experiment in experiments:
        result_row = {}
        for key in data_sets.keys():
            result_row[key] = np.count_nonzero(
                transformation(experiment.predictions[key]) < 0.0
            )
        results[experiment.name] = result_row
    return pd.DataFrame.from_dict(results, orient="index")


count_negative_gaps()
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs      0           0                 0            3
# krr_two_body           0           0                 0            0
# krr_three_body         0           0                 0            0
# nn_standard_racs       0           0                 0            0
# nn_two_body            2           0                 0            1
# nn_three_body          1           0                 0            0

# %%
data_sets["ligand_test"][
    np.any(gap_both(experiments[0].predictions["ligand_test"]) < 0, axis=1)
]
# Out:
#                                                name metal  ox  high_spin  \
# 17   co_2_thiane_thiane_thiane_thiane_thiane_thiane    co   2          4
# 61   fe_3_thiane_thiane_thiane_thiane_thiane_thiane    fe   3          6
# 123  cr_3_thiane_thiane_thiane_thiane_thiane_thiane    cr   3          4
#
#      spin_splitting_kcal/mol  energetic_homo_ls_eV  energetic_homo_hs_eV  \
# 17                 -6.649775            -11.246466            -11.540349
# 61                 -8.337003            -14.911840            -14.824763
# 123               -27.275012            -15.026127            -14.982589
#
#      energetic_lumo_ls_eV  energetic_lumo_hs_eV  energetic_gap_ls_eV  ...  \
# 17              -8.968873             -8.740297             2.277593  ...
# 61             -12.832890            -12.773025             2.078950  ...
# 123            -12.212470            -12.381181             2.813657  ...
#
#      lig6_D_T_1  lig6_D_S_1  lig6_D_Z_2  lig6_D_chi_2  lig6_D_T_2  lig6_D_S_2  \
# 17         -4.0        0.58        80.0          1.58         0.0        3.54
# 61         -4.0        0.58        80.0          1.58         0.0        3.54
# 123        -4.0        0.58        80.0          1.58         0.0        3.54
#
#      lig6_D_Z_3  lig6_D_chi_3  lig6_D_T_3  lig6_D_S_3
# 17         70.0          1.55         2.0        3.25
# 61         70.0          1.55         2.0        3.25
# 123        70.0          1.55         2.0        3.25
#
# [3 rows x 393 columns]

# %%
data_sets["ligand_test"][
    np.any(gap_both(experiments[4].predictions["ligand_test"]) < 0, axis=1)
]
# Out:
#                                                name metal  ox  high_spin  \
# 123  cr_3_thiane_thiane_thiane_thiane_thiane_thiane    cr   3          4
#
#      spin_splitting_kcal/mol  energetic_homo_ls_eV  energetic_homo_hs_eV  \
# 123               -27.275012            -15.026127            -14.982589
#
#      energetic_lumo_ls_eV  energetic_lumo_hs_eV  energetic_gap_ls_eV  ...  \
# 123             -12.21247            -12.381181             2.813657  ...
#
#      lig6_D_T_1  lig6_D_S_1  lig6_D_Z_2  lig6_D_chi_2  lig6_D_T_2  lig6_D_S_2  \
# 123        -4.0        0.58        80.0          1.58         0.0        3.54
#
#      lig6_D_Z_3  lig6_D_chi_3  lig6_D_T_3  lig6_D_S_3
# 123        70.0          1.55         2.0        3.25
#
# [1 rows x 393 columns]

# %%
data_sets["train"][np.any(gap_both(experiments[4].predictions["train"]) < 0, axis=1)]
# Out:
#                                             name metal  ox  high_spin  \
# 447  fe_3_furan_furan_furan_furan_carbonyl_furan    fe   3          6
# 449      fe_3_furan_furan_furan_furan_misc_furan    fe   3          6
#
#      spin_splitting_kcal/mol  energetic_homo_ls_eV  energetic_homo_hs_eV  \
# 447               -23.713989            -15.842469            -15.654710
# 449               -21.943644            -15.461510            -15.230213
#
#      energetic_lumo_ls_eV  energetic_lumo_hs_eV  energetic_gap_ls_eV  ...  \
# 447            -15.241097            -15.012522             0.601372  ...
# 449            -14.713196            -14.615235             0.748313  ...
#
#      lig6_D_T_1  lig6_D_S_1  lig6_D_Z_2  lig6_D_chi_2  lig6_D_T_2  lig6_D_S_2  \
# 447        -2.0        -0.2        18.0          4.26         0.0         0.5
# 449        -2.0        -0.2        18.0          4.26         0.0         0.5
#
#      lig6_D_Z_3  lig6_D_chi_3  lig6_D_T_3  lig6_D_S_3
# 447        14.0          2.48         2.0         0.7
# 449        14.0          2.48         2.0         0.7
#
# [2 rows x 393 columns]

# %%
data_sets["train"][np.any(gap_both(experiments[5].predictions["train"]) < 0, axis=1)]
# Out:
#                                             name metal  ox  high_spin  \
# 447  fe_3_furan_furan_furan_furan_carbonyl_furan    fe   3          6
#
#      spin_splitting_kcal/mol  energetic_homo_ls_eV  energetic_homo_hs_eV  \
# 447               -23.713989            -15.842469             -15.65471
#
#      energetic_lumo_ls_eV  energetic_lumo_hs_eV  energetic_gap_ls_eV  ...  \
# 447            -15.241097            -15.012522             0.601372  ...
#
#      lig6_D_T_1  lig6_D_S_1  lig6_D_Z_2  lig6_D_chi_2  lig6_D_T_2  lig6_D_S_2  \
# 447        -2.0        -0.2        18.0          4.26         0.0         0.5
#
#      lig6_D_Z_3  lig6_D_chi_3  lig6_D_T_3  lig6_D_S_3
# 447        14.0          2.48         2.0         0.7
#
# [1 rows x 393 columns]

# %%
evaluate_metric(mean_absolute_error, transformation=gap_both).round(2)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs   0.16        0.52              0.45         0.80
# krr_two_body        0.35        0.45              0.34         0.72
# krr_three_body      0.20        0.41              0.26         0.61
# nn_standard_racs    0.34        0.43              0.50         0.63
# nn_two_body         0.39        0.44              0.42         0.54
# nn_three_body       0.34        0.39              0.94         0.53

# %%
evaluate_metric(r2_score, transformation=gap_both).round(3)
# Out:
#                    train  validation  composition_test  ligand_test
# krr_standard_racs  0.960       0.550             0.657        0.079
# krr_two_body       0.808       0.681             0.808        0.338
# krr_three_body     0.925       0.720             0.874        0.504
# nn_standard_racs   0.848       0.731             0.639        0.454
# nn_two_body        0.782       0.697             0.731        0.573
# nn_three_body      0.845       0.757            -0.050        0.600

# %%
metal_dependence("ligand_test", mean_absolute_error, transformation=gap_both).round(2)
# Out:
#                     cr3   cr2   mn3   mn2   fe3   fe2   co3   co2   ox2   ox3  \
# krr_standard_racs  1.03  0.56  0.74  0.83  0.93  0.70  0.93  0.80  0.72  0.93
# krr_two_body       1.10  0.59  0.55  0.57  0.84  0.59  0.78  0.71  0.62  0.87
# krr_three_body     1.02  0.40  0.45  0.36  0.80  0.51  0.84  0.60  0.48  0.82
# nn_standard_racs   0.83  0.44  0.54  0.47  0.64  0.55  0.79  0.77  0.57  0.72
# nn_two_body        0.97  0.28  0.28  0.38  0.76  0.42  0.88  0.51  0.40  0.77
# nn_three_body      0.85  0.39  0.31  0.46  0.44  0.50  0.54  0.63  0.50  0.58
#
#                     all
# krr_standard_racs  0.80
# krr_two_body       0.72
# krr_three_body     0.61
# nn_standard_racs   0.63
# nn_two_body        0.54
# nn_three_body      0.53

# %%
ligand_dependence(mean_absolute_error, transformation=gap_both).round(2)
# Out:
#                        count  krr_standard_racs  krr_two_body  krr_three_body  \
# 4H-pyran                   3               0.55          0.37            0.44
# [OH]-[CH]=[CH]-[OH]        4               0.75          0.85            0.94
# bifuran                    4               0.56          0.44            0.37
# pyridine-N-oxide           7               0.96          1.03            0.83
# acrylamide                 7               0.41          0.67            0.52
# dmf                        8               0.87          0.69            0.35
# thiophene                  5               0.74          0.94            0.49
# thiane                     5               2.84          0.91            0.70
# 4H-thiopyran               5               0.35          0.54            0.52
# oxazoline                  7               0.88          0.73            0.53
# thioazole                  7               0.53          0.87            1.07
# [NH]=[CH]-[OH]             6               0.68          0.36            0.46
# [PH]=[CH]-[OH]             6               0.40          0.51            0.41
# [NH2]-[NH]-[NH]-[NH2]      5               0.51          0.57            0.51
# 1H-tetrazole               8               1.36          1.25            1.21
# 1H-triazole                7               0.80          0.49            0.56
# thioformaldehyde           6               0.50          0.47            0.41
# [NH2]-[O]-[O]-[NH2]        6               0.53          0.48            0.43
# bipyrimidine               8               1.24          0.81            0.63
# [PH2]-[CH2]-[OH]           7               0.48          0.65            0.46
# [PH2]-[NH]-[NH]-[PH2]      6               0.72          0.97            0.70
#
#                        nn_standard_racs  nn_two_body  nn_three_body
# 4H-pyran                           1.34         0.33           1.11
# [OH]-[CH]=[CH]-[OH]                0.63         0.87           0.99
# bifuran                            1.11         0.31           0.86
# pyridine-N-oxide                   0.85         0.67           0.67
# acrylamide                         0.33         0.44           0.36
# dmf                                0.29         0.36           0.48
# thiophene                          0.30         0.24           0.95
# thiane                             0.38         1.20           0.38
# 4H-thiopyran                       0.80         0.47           1.19
# oxazoline                          0.71         0.60           0.38
# thioazole                          1.15         0.82           0.30
# [NH]=[CH]-[OH]                     0.83         0.40           0.41
# [PH]=[CH]-[OH]                     0.41         0.71           0.65
# [NH2]-[NH]-[NH]-[NH2]              0.32         0.48           0.53
# 1H-tetrazole                       1.32         0.86           0.49
# 1H-triazole                        0.83         0.39           0.31
# thioformaldehyde                   0.28         0.24           0.24
# [NH2]-[O]-[O]-[NH2]                0.16         0.31           0.26
# bipyrimidine                       0.45         0.38           0.39
# [PH2]-[CH2]-[OH]                   0.32         0.61           0.58
# [PH2]-[NH]-[NH]-[PH2]              0.62         0.61           0.57
