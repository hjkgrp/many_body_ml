# %%
import numpy as np
import pandas as pd
import networkx as nx
from pathlib import Path
from ase.io import read
from mbeml.featurization import (
    generate_ligand_racs_names,
    generate_standard_racs_names,
    sort_connecting_atoms,
    featurize_single_ligand,
)
from molSimplify.Classes.mol3D import mol3D
from molSimplify.Classes.mol2D import Mol2D
from molSimplify.Classes.ligand import ligand_breakdown, ligand_assign_consistent
from molSimplify.Informatics.lacRACAssemble import get_descriptor_vector

# %%
raw_data_path = Path("../../raw_data")
data_path = Path("../../data")
data_sets = {
    "training": pd.read_csv(raw_data_path / "training" / "training_data_raw.csv"),
    "validation": pd.read_csv(raw_data_path / "validation" / "validation_data_raw.csv"),
    "ligand_test": pd.read_csv(raw_data_path / "ligand_test" / "ligand_test_data_raw.csv"),
    "composition_test": pd.read_csv(raw_data_path / "composition_test" / "composition_test_data_raw.csv"),
}

# %%
# dictionary assigning the molecular graph determinant to a charge per connecting atom
ligand_charges = {
    "6aef01e37dbae6d1036490f90be7fdfb": -1,  # fluoride, graph_det=18.9984
    "3dc71de014d4aa968cdd9f7c1e905feb": -2,  # sulfide, graph_det=32.065
    "481b474701a5d44d8bc0a1051f702ad0": -1,  # chloride, graph_det=35.452999999
    "8c49bdf7d036bdf3178afbdb02b59e5f": -1,  # iodide, graph_det=126.90446999
    "8991adadca2e8cc23e62278399df44a1": -1,  # hydroxyl [OH-], graph_det=-243.9154775
    "09642cb93892875b5495ff15993a6289": -1,  # cyanide, graph_det=-28133.19404
    "608a852d63f3b4f49956bae07e2b3f8c": -2,  # [O-][O-], graph_det=-65270.18935
    "247db616eed8055e98564c9c3d17734e": -1,  # NC[O-], graph_det=-967339.6416
    "1e18033c0b1c215888a09256d7639180": -1,  # ox, graph_det=138760516791
    "0dfc6836e022406f1be7b5627451d590": -0.5,  # acac, graph_det=-2.822252628e+16
    "0bcd1e34289690552dd5b876ac74361e": -0.5,  # porphyrin, graph_det=2.6410120150e+51
}

# %%
standard_racs_names = generate_standard_racs_names()
ligand_racs_names = generate_ligand_racs_names()

def featurize_data_set(df_raw, xyzs_dir):
    df_out = df_raw.copy()
    
    for index, row in df_out.iterrows():
        # ############################################# #
        # Use molSimplify to evaluate the standard-RACs #
        # ############################################# #
        mol = mol3D()
        # Use low spin geometry for featurization
        low_spin = 2 if row["high_spin"] % 2 == 0 else 1
        mol.readfromxyz(xyzs_dir / f"{row['name']}_{low_spin}.xyz")
        _, standard_racs = get_descriptor_vector(mol)

        liglist, ligdents, ligcons = ligand_breakdown(mol)
        (
            ax_ligand_list,
            eq_ligand_list,
            _,
            _,
            ax_con_int_list,
            eq_con_int_list,
            _,
            _,
            _,
        ) = ligand_assign_consistent(mol, liglist, ligdents, ligcons, loud=False)
        # These are somewhat difficult to calculate given that there are "fractional" ligands in the ligand_list.
        # This is accounted for by the multipling the fractional ligand charge with the number of connecting atoms in the subset
        axial_charge = sum(
            [
                ligand_charges.get(Mol2D.from_mol3d(lig.mol).graph_hash(), 0) * len(con)
                for lig, con in zip(ax_ligand_list, ax_con_int_list)
            ]
        )
        equatorial_charge = sum(
            [
                ligand_charges.get(Mol2D.from_mol3d(lig.mol).graph_hash(), 0) * len(con)
                for lig, con in zip(eq_ligand_list, eq_con_int_list)
            ]
        )
        standard_racs[1] = axial_charge / len(ax_ligand_list)
        standard_racs[3] = equatorial_charge / len(eq_ligand_list)

        df_out.loc[index, standard_racs_names] = standard_racs
    

        # #################### #
        # evaluate ligand-RACs #
        # #################### #
        ase_atoms = read(xyzs_dir / f"{row['name']}_{low_spin}.xyz")
        mol2D = Mol2D.from_mol3d(mol)
        # Check that there is only one metal and that it is the first atom
        assert mol2D.find_metal() == [0]

        connecting_atoms = sort_connecting_atoms(ase_atoms, list(mol2D.neighbors(0)))

        split_graph = mol2D.copy()
        # Remove edges from center (index 0) to the connecting atoms
        split_graph.remove_edges_from([(0, c) for c in connecting_atoms])
        ligand_graphs = [split_graph.subgraph(gi) for gi in nx.connected_components(split_graph)][1:]
        
        ligand_racs = np.zeros((6, 33))
        for ci, c in enumerate(connecting_atoms):
            ligand_racs[ci, 1:] = featurize_single_ligand(split_graph, c, depth=3)

            # Kazy way of finding correct subgraph for the connecting atom c
            for lig_graph in ligand_graphs:            
                if c in lig_graph:
                    break
            else:
                raise ValueError(f'Unable to find ligand corresponding to connecting atom {c}')
            
            lig_hash = lig_graph.graph_hash()
            if lig_hash in ligand_charges:
                ligcharge = ligand_charges[lig_hash]
            else:
                ligcharge = 0.0
            ligand_racs[ci, 0] = ligcharge
            if lig_graph.graph_determinant() in ligand_charges:
                print(lig_graph.graph_determinant(), lig_graph.graph_hash())
        
        df_out.loc[index, ligand_racs_names] = ligand_racs.flatten()
    return df_out

# %%
for key, df_raw in data_sets.items():
    df = featurize_data_set(df_raw, raw_data_path / key / "xyzs")
    df.to_csv(data_path / f"{key}_data.csv")

# %%
df_lig_test = featurize_data_set(data_sets["ligand_test"], raw_data_path / "ligand_test" / "xyzs")
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is 08/16/2024 12:29, XYZ structure generated by mol3D Class, molSimplify)

# %%
df_lig_test_ref = pd.read_csv(data_path / "ligand_test_data.csv")
pd.testing.assert_frame_equal(df_lig_test, df_lig_test_ref)

# %%
df_comp_test = featurize_data_set(data_sets["composition_test"], raw_data_path / "composition_test" / "xyzs")

# %%
df_comp_test_ref = pd.read_csv(data_path / "composition_test_data.csv")
pd.testing.assert_frame_equal(df_comp_test, df_comp_test_ref)

# %%
df_val = featurize_data_set(data_sets["validation"], raw_data_path / "validation" / "xyzs")

# %%
df_val_ref = pd.read_csv(data_path / "validation_data.csv")
pd.testing.assert_frame_equal(df_val, df_val_ref)

# %%
df_train = featurize_data_set(data_sets["training"], raw_data_path / "training" / "xyzs")

# %%
df_train_ref = pd.read_csv(data_path / "training_data.csv")
pd.testing.assert_frame_equal(df_train, df_train_ref)

# %%
df_raw = pd.read_csv(raw_data_path / "ligand_test" / "ligand_test_data_raw.csv")
df_lig_test = pd.read_csv("/home/ralf/Dropbox (MIT)/many_body_expansion/data/new_calculations/ligand_generalization_set/ligand_generalization_data.csv")

# %%
def ligand_renaming(lig: str):
    if lig == "bipyrimidine":
        return "bidiazine"
    return lig

for index, row in df_raw.iterrows():
    metal, ox, lig1, lig2, lig3, lig4, lig5, lig6 = row["name"].split("_")

    print(metal, ox, lig1)
    mask = (
        (df_lig_test["metal"] == metal)
        & (df_lig_test["ox"] == int(ox))
        & (df_lig_test["lig1"] == ligand_renaming(lig1))
        & (df_lig_test["lig2"] == ligand_renaming(lig2))
        & (df_lig_test["lig3"] == ligand_renaming(lig3))
        & (df_lig_test["lig4"] == ligand_renaming(lig4))
        & (df_lig_test["lig5"] == ligand_renaming(lig5))
        & (df_lig_test["lig6"] == ligand_renaming(lig6))
    )
    assert len(df_lig_test[mask])  == 2
    # Loop over the two spins and write .xyz
    for _, spin in df_lig_test[mask].iterrows():
        with open(raw_data_path / "ligand_test" / "xyzs" / f"{row['name']}_{spin['spin']}.xyz", "w") as fout:
            fout.write(spin["opt_geo"].replace("\t", "    "))
# Out:
# co 2 1H-tetrazole
# co 2 1H-triazole
# co 2 4H-pyran
# co 2 4H-thiopyran
# co 2 [NH]=[CH]-[OH]
# co 2 [PH2]-[CH2]-[OH]
# co 2 [PH2]-[NH]-[NH]-[PH2]
# co 2 [PH]=[CH]-[OH]
# co 2 [NH2]-[NH]-[NH]-[NH2]
# co 2 [NH2]-[O]-[O]-[NH2]
# co 2 [OH]-[CH]=[CH]-[OH]
# co 2 acrylamide
# co 2 bipyrimidine
# co 2 bifuran
# co 2 dmf
# co 2 oxazoline
# co 2 pyridine-N-oxide
# co 2 thiane
# co 2 thioazole
# co 2 thioformaldehyde
# co 2 thiophene
# co 3 1H-tetrazole
# co 3 1H-triazole
# co 3 [PH2]-[CH2]-[OH]
# co 3 acrylamide
# co 3 bipyrimidine
# co 3 dmf
# co 3 oxazoline
# co 3 thioazole
# fe 2 1H-tetrazole
# fe 2 1H-triazole
# fe 2 4H-pyran
# fe 2 4H-thiopyran
# fe 2 [NH]=[CH]-[OH]
# fe 2 [PH2]-[CH2]-[OH]
# fe 2 [PH2]-[NH]-[NH]-[PH2]
# fe 2 [PH]=[CH]-[OH]
# fe 2 [NH2]-[NH]-[NH]-[NH2]
# fe 2 [NH2]-[O]-[O]-[NH2]
# fe 2 [OH]-[CH]=[CH]-[OH]
# fe 2 acrylamide
# fe 2 bipyrimidine
# fe 2 bifuran
# fe 2 dmf
# fe 2 oxazoline
# fe 2 pyridine-N-oxide
# fe 2 thiane
# fe 2 thioazole
# fe 2 thioformaldehyde
# fe 2 thiophene
# fe 3 1H-tetrazole
# fe 3 1H-triazole
# fe 3 [NH]=[CH]-[OH]
# fe 3 [PH2]-[CH2]-[OH]
# fe 3 [PH2]-[NH]-[NH]-[PH2]
# fe 3 [PH]=[CH]-[OH]
# fe 3 [NH2]-[O]-[O]-[NH2]
# fe 3 acrylamide
# fe 3 bipyrimidine
# fe 3 dmf
# fe 3 pyridine-N-oxide
# fe 3 thiane
# fe 3 thioazole
# fe 3 thioformaldehyde
# mn 2 1H-tetrazole
# mn 2 1H-triazole
# mn 2 4H-thiopyran
# mn 2 [NH]=[CH]-[OH]
# mn 2 [PH2]-[CH2]-[OH]
# mn 2 [PH2]-[NH]-[NH]-[PH2]
# mn 2 [PH]=[CH]-[OH]
# mn 2 [NH2]-[NH]-[NH]-[NH2]
# mn 2 [NH2]-[O]-[O]-[NH2]
# mn 2 acrylamide
# mn 2 bipyrimidine
# mn 2 bifuran
# mn 2 dmf
# mn 2 oxazoline
# mn 2 pyridine-N-oxide
# mn 2 thiane
# mn 2 thioformaldehyde
# mn 2 thiophene
# mn 3 1H-tetrazole
# mn 3 1H-triazole
# mn 3 [NH]=[CH]-[OH]
# mn 3 acrylamide
# mn 3 bipyrimidine
# mn 3 dmf
# mn 3 oxazoline
# mn 3 pyridine-N-oxide
# mn 3 thioazole
# cr 2 1H-tetrazole
# cr 2 1H-triazole
# cr 2 4H-pyran
# cr 2 4H-thiopyran
# cr 2 [PH2]-[CH2]-[OH]
# cr 2 [PH2]-[NH]-[NH]-[PH2]
# cr 2 [PH]=[CH]-[OH]
# cr 2 [NH2]-[NH]-[NH]-[NH2]
# cr 2 [NH2]-[O]-[O]-[NH2]
# cr 2 [OH]-[CH]=[CH]-[OH]
# cr 2 bipyrimidine
# cr 2 bifuran
# cr 2 dmf
# cr 2 oxazoline
# cr 2 pyridine-N-oxide
# cr 2 thioazole
# cr 2 thioformaldehyde
# cr 2 thiophene
# cr 3 1H-tetrazole
# cr 3 4H-thiopyran
# cr 3 [NH]=[CH]-[OH]
# cr 3 [PH2]-[CH2]-[OH]
# cr 3 [PH2]-[NH]-[NH]-[PH2]
# cr 3 [PH]=[CH]-[OH]
# cr 3 [NH2]-[NH]-[NH]-[NH2]
# cr 3 [NH2]-[O]-[O]-[NH2]
# cr 3 [OH]-[CH]=[CH]-[OH]
# cr 3 acrylamide
# cr 3 bipyrimidine
# cr 3 dmf
# cr 3 oxazoline
# cr 3 pyridine-N-oxide
# cr 3 thiane
# cr 3 thioazole
# cr 3 thioformaldehyde
# cr 3 thiophene

# %%
df_lig_test
# Out:
#     metal  ox  spin              lig1              lig2              lig3  \
# 0      co   2     2      1H-tetrazole      1H-tetrazole      1H-tetrazole
# 1      co   2     4      1H-tetrazole      1H-tetrazole      1H-tetrazole
# 2      co   2     2       1H-triazole       1H-triazole       1H-triazole
# 3      co   2     4       1H-triazole       1H-triazole       1H-triazole
# 4      co   2     2          4H-pyran          4H-pyran          4H-pyran
# ..    ...  ..   ...               ...               ...               ...
# 363    cr   3     4         thioazole         thioazole         thioazole
# 364    cr   3     2  thioformaldehyde  thioformaldehyde  thioformaldehyde
# 365    cr   3     4  thioformaldehyde  thioformaldehyde  thioformaldehyde
# 366    cr   3     2         thiophene         thiophene         thiophene
# 367    cr   3     4         thiophene         thiophene         thiophene
#
#                  lig4              lig5              lig6       energy  ...  \
# 0        1H-tetrazole      1H-tetrazole      1H-tetrazole -1694.285329  ...
# 1        1H-tetrazole      1H-tetrazole      1H-tetrazole -1694.294977  ...
# 2         1H-triazole       1H-triazole       1H-triazole -1598.144214  ...
# 3         1H-triazole       1H-triazole       1H-triazole -1598.150651  ...
# 4            4H-pyran          4H-pyran          4H-pyran -1760.521993  ...
# ..                ...               ...               ...          ...  ...
# 363         thioazole         thioazole         thioazole -3499.871514  ...
# 364  thioformaldehyde  thioformaldehyde  thioformaldehyde -2710.102889  ...
# 365  thioformaldehyde  thioformaldehyde  thioformaldehyde -2710.146511  ...
# 366         thiophene         thiophene         thiophene -3403.325417  ...
# 367         thiophene         thiophene         thiophene -3403.368239  ...
#
#      metal_spin_target  ss_flag  metal_spin_flag  geo_flag  mol_graph_det  \
# 0                  1.0      1.0              1.0       1.0  -3.369050e+68
# 1                  3.0      1.0              1.0       1.0  -3.369050e+68
# 2                  1.0      1.0              1.0       1.0  -8.394981e+63
# 3                  3.0      1.0              1.0       1.0  -8.394981e+63
# 4                  1.0      0.0              1.0       1.0  -5.015494e+77
# ..                 ...      ...              ...       ...            ...
# 363                3.0      1.0              1.0       1.0  -2.814787e+74
# 364                1.0      0.0              1.0       1.0  -4.906169e+35
# 365                3.0      1.0              1.0       1.0  -4.906169e+35
# 366                1.0      0.0              0.0       1.0  -7.745070e+69
# 367                3.0      1.0              1.0       1.0  -7.745070e+69
#
#                                                opt_geo  alphaHOMO  alphaLUMO  \
# 0    43\n11/21/2023 17:07, XYZ structure generated ...    -0.4669    -0.3009
# 1    43\n11/21/2023 17:07, XYZ structure generated ...    -0.5012    -0.2471
# 2    49\n11/21/2023 17:07, XYZ structure generated ...    -0.4276    -0.2641
# 3    49\n11/21/2023 17:07, XYZ structure generated ...    -0.4550    -0.2189
# 4    73\n11/21/2023 17:07, XYZ structure generated ...    -0.4191    -0.3830
# ..                                                 ...        ...        ...
# 363  49\n11/21/2023 17:08, XYZ structure generated ...    -0.5856    -0.4340
# 364  25\n11/21/2023 17:08, XYZ structure generated ...    -0.6637    -0.5461
# 365  25\n11/21/2023 17:08, XYZ structure generated ...    -0.6594    -0.5326
# 366  55\n11/21/2023 17:08, XYZ structure generated ...    -0.5532    -0.5330
# 367  55\n11/21/2023 17:08, XYZ structure generated ...    -0.5656    -0.5102
#
#      betaHOMO  betaLUMO
# 0     -0.4864   -0.2676
# 1     -0.5024   -0.3237
# 2     -0.4472   -0.2307
# 3     -0.4588   -0.2944
# 4     -0.4222   -0.2479
# ..        ...       ...
# 363   -0.5849   -0.4285
# 364   -0.6671   -0.5366
# 365   -0.6686   -0.5202
# 366   -0.5601   -0.4307
# 367   -0.5656   -0.4457
#
# [368 rows x 26 columns]

# %%
df_raw["name"].str.split("_").str.get(2).unique()
# Out:
# array(['1H-tetrazole', '1H-triazole', '4H-pyran', '4H-thiopyran',
#        '[NH]=[CH]-[OH]', '[PH2]-[CH2]-[OH]', '[PH2]-[NH]-[NH]-[PH2]',
#        '[PH]=[CH]-[OH]', '[NH2]-[NH]-[NH]-[NH2]', '[NH2]-[O]-[O]-[NH2]',
#        '[OH]-[CH]=[CH]-[OH]', 'acrylamide', 'bipyrimidine', 'bifuran',
#        'dmf', 'oxazoline', 'pyridine-N-oxide', 'thiane', 'thioazole',
#        'thioformaldehyde', 'thiophene'], dtype=object)

# %%
df_raw = pd.read_csv(raw_data_path / "composition_test" / "composition_test_data_raw.csv")
df_comp_test = pd.read_csv("/home/ralf/Dropbox (MIT)/many_body_expansion/data/new_calculations/interpolation_set/ligand_composition_data2.csv")

# %%
for index, row in df_raw.iterrows():
    metal, ox, lig1, lig2, lig3, lig4, lig5, lig6 = row["name"].split("_")

    print(metal, ox, lig1)
    mask = (
        (df_comp_test["metal"] == metal)
        & (df_comp_test["ox"] == int(ox))
        & (df_comp_test["lig1"] == lig1)
        & (df_comp_test["lig2"] == lig2)
        & (df_comp_test["lig3"] == lig3)
        & (df_comp_test["lig4"] == lig4)
        & (df_comp_test["lig5"] == lig5)
        & (df_comp_test["lig6"] == lig6)
    )
    assert len(df_comp_test[mask])  == 2
    # Loop over the two spins and write .xyz
    for _, spin in df_comp_test[mask].iterrows():
        with open(raw_data_path / "composition_test" / "xyzs" / f"{row['name']}_{spin['spin']}.xyz", "w") as fout:
            fout.write(spin["opt_geo"].replace("\t", "    "))
# Out:
# name                       co_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -13.998205
# energetic_homo_ls_eV                                              -14.968983
# energetic_homo_hs_eV                                              -15.268309
# energetic_lumo_ls_eV                                              -10.321279
# energetic_lumo_hs_eV                                              -10.432845
# energetic_gap_ls_eV                                                 4.647705
# energetic_gap_hs_eV                                                 4.835463
# Name: 0, dtype: object
# co 2 hydrogencyanide
# name                       co_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -16.550004
# energetic_homo_ls_eV                                              -14.952657
# energetic_homo_hs_eV                                              -15.164905
# energetic_lumo_ls_eV                                               -10.22876
# energetic_lumo_hs_eV                                              -10.196106
# energetic_gap_ls_eV                                                 4.723897
# energetic_gap_hs_eV                                                 4.968799
# Name: 1, dtype: object
# co 2 hydrogencyanide
# name                       co_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -15.093206
# energetic_homo_ls_eV                                              -14.585303
# energetic_homo_hs_eV                                              -14.928166
# energetic_lumo_ls_eV                                              -10.353932
# energetic_lumo_hs_eV                                              -10.392028
# energetic_gap_ls_eV                                                 4.231371
# energetic_gap_hs_eV                                                 4.536138
# Name: 2, dtype: object
# co 2 hydrogencyanide
# name                       co_2_methanol_methanol_hydrogencyanide_hydroge...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -11.962334
# energetic_homo_ls_eV                                              -14.519996
# energetic_homo_hs_eV                                              -14.792109
# energetic_lumo_ls_eV                                              -10.351211
# energetic_lumo_hs_eV                                              -10.647815
# energetic_gap_ls_eV                                                 4.168784
# energetic_gap_hs_eV                                                 4.144294
# Name: 3, dtype: object
# co 2 methanol
# name                       co_2_methanol_methanol_methanol_hydrogencyanid...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -16.494572
# energetic_homo_ls_eV                                              -14.767619
# energetic_homo_hs_eV                                              -15.047896
# energetic_lumo_ls_eV                                              -10.269577
# energetic_lumo_hs_eV                                              -10.163453
# energetic_gap_ls_eV                                                 4.498042
# energetic_gap_hs_eV                                                 4.884444
# Name: 4, dtype: object
# co 2 methanol
# name                       co_2_methanol_methanol_methanol_hydrogencyanid...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -16.300323
# energetic_homo_ls_eV                                              -14.612514
# energetic_homo_hs_eV                                              -14.993474
# energetic_lumo_ls_eV                                              -10.296788
# energetic_lumo_hs_eV                                               -10.13352
# energetic_gap_ls_eV                                                 4.315726
# energetic_gap_hs_eV                                                 4.859954
# Name: 5, dtype: object
# co 2 methanol
# name                       co_2_methanol_methanol_methanol_methanol_hydro...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -12.538742
# energetic_homo_ls_eV                                              -14.835648
# energetic_homo_hs_eV                                               -14.62612
# energetic_lumo_ls_eV                                               -10.20427
# energetic_lumo_hs_eV                                              -10.356654
# energetic_gap_ls_eV                                                 4.631378
# energetic_gap_hs_eV                                                 4.269466
# Name: 6, dtype: object
# co 2 methanol
# name                       co_2_methanol_methanol_methanol_methanol_metha...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -16.306766
# energetic_homo_ls_eV                                              -14.732244
# energetic_homo_hs_eV                                              -15.012522
# energetic_lumo_ls_eV                                              -10.168895
# energetic_lumo_hs_eV                                              -10.160732
# energetic_gap_ls_eV                                                 4.563349
# energetic_gap_hs_eV                                                  4.85179
# Name: 7, dtype: object
# co 2 methanol
# name                       co_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            -5.667077
# energetic_homo_ls_eV                                               -14.86558
# energetic_homo_hs_eV                                              -15.611172
# energetic_lumo_ls_eV                                              -10.100866
# energetic_lumo_hs_eV                                              -10.653258
# energetic_gap_ls_eV                                                 4.764714
# energetic_gap_hs_eV                                                 4.957915
# Name: 8, dtype: object
# co 2 hydrogencyanide
# name                       co_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            -3.484406
# energetic_homo_ls_eV                                              -14.645168
# energetic_homo_hs_eV                                              -15.284636
# energetic_lumo_ls_eV                                              -10.032838
# energetic_lumo_hs_eV                                              -10.642373
# energetic_gap_ls_eV                                                  4.61233
# energetic_gap_hs_eV                                                 4.642262
# Name: 9, dtype: object
# co 2 hydrogencyanide
# name                       co_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            -1.461806
# energetic_homo_ls_eV                                              -14.903676
# energetic_homo_hs_eV                                              -15.401644
# energetic_lumo_ls_eV                                               -9.864127
# energetic_lumo_hs_eV                                              -10.650536
# energetic_gap_ls_eV                                                 5.039549
# energetic_gap_hs_eV                                                 4.751108
# Name: 10, dtype: object
# co 2 hydrogencyanide
# name                       co_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                              4.92144
# energetic_homo_ls_eV                                              -14.881907
# energetic_homo_hs_eV                                              -15.045175
# energetic_lumo_ls_eV                                               -9.646436
# energetic_lumo_hs_eV                                              -10.636931
# energetic_gap_ls_eV                                                 5.235471
# energetic_gap_hs_eV                                                 4.408245
# Name: 11, dtype: object
# co 2 hydrogencyanide
# name                       co_2_hydrogencyanide_hydrogencyanide_hydrogeni...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                             0.543544
# energetic_homo_ls_eV                                              -14.275093
# energetic_homo_hs_eV                                              -15.398923
# energetic_lumo_ls_eV                                               -9.842358
# energetic_lumo_hs_eV                                              -10.650536
# energetic_gap_ls_eV                                                 4.432735
# energetic_gap_hs_eV                                                 4.748387
# Name: 12, dtype: object
# co 2 hydrogencyanide
# name                       co_2_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                             7.102474
# energetic_homo_ls_eV                                              -14.209786
# energetic_homo_hs_eV                                              -14.990753
# energetic_lumo_ls_eV                                               -9.616504
# energetic_lumo_hs_eV                                              -10.650536
# energetic_gap_ls_eV                                                 4.593282
# energetic_gap_hs_eV                                                 4.340216
# Name: 13, dtype: object
# co 2 hydrogenisocyanide
# name                       co_2_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            14.130596
# energetic_homo_ls_eV                                               -14.89007
# energetic_homo_hs_eV                                               -14.69687
# energetic_lumo_ls_eV                                               -9.379765
# energetic_lumo_hs_eV                                              -10.626046
# energetic_gap_ls_eV                                                 5.510306
# energetic_gap_hs_eV                                                 4.070823
# Name: 14, dtype: object
# co 2 hydrogenisocyanide
# name                       co_2_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            12.982478
# energetic_homo_ls_eV                                               -14.29142
# energetic_homo_hs_eV                                              -14.764898
# energetic_lumo_ls_eV                                               -9.360717
# energetic_lumo_hs_eV                                              -10.645094
# energetic_gap_ls_eV                                                 4.930703
# energetic_gap_hs_eV                                                 4.119804
# Name: 15, dtype: object
# co 2 hydrogenisocyanide
# name                       co_2_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            10.729388
# energetic_homo_ls_eV                                              -14.280535
# energetic_homo_hs_eV                                              -14.729523
# energetic_lumo_ls_eV                                                -9.41514
# energetic_lumo_hs_eV                                              -10.421961
# energetic_gap_ls_eV                                                 4.865396
# energetic_gap_hs_eV                                                 4.307562
# Name: 16, dtype: object
# co 2 hydrogenisocyanide
# name                       co_2_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                             6.145001
# energetic_homo_ls_eV                                              -14.381218
# energetic_homo_hs_eV                                              -14.800273
# energetic_lumo_ls_eV                                               -9.466841
# energetic_lumo_hs_eV                                              -10.171616
# energetic_gap_ls_eV                                                 4.914376
# energetic_gap_hs_eV                                                 4.628657
# Name: 17, dtype: object
# co 2 hydrogenisocyanide
# name                       co_2_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                             3.563101
# energetic_homo_ls_eV                                              -14.261487
# energetic_homo_hs_eV                                              -14.898234
# energetic_lumo_ls_eV                                               -9.845079
# energetic_lumo_hs_eV                                              -10.413797
# energetic_gap_ls_eV                                                 4.416408
# energetic_gap_hs_eV                                                 4.484436
# Name: 18, dtype: object
# co 2 hydrogenisocyanide
# name                       co_2_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            -0.506959
# energetic_homo_ls_eV                                              -14.451967
# energetic_homo_hs_eV                                              -14.993474
# energetic_lumo_ls_eV                                                -9.89406
# energetic_lumo_hs_eV                                              -10.226039
# energetic_gap_ls_eV                                                 4.557907
# energetic_gap_hs_eV                                                 4.767435
# Name: 19, dtype: object
# co 2 hydrogenisocyanide
# name                       co_2_hydrogenisocyanide_hydrogenisocyanide_met...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            -5.385966
# energetic_homo_ls_eV                                              -14.174411
# energetic_homo_hs_eV                                              -14.971705
# energetic_lumo_ls_eV                                              -10.152568
# energetic_lumo_hs_eV                                               -10.41924
# energetic_gap_ls_eV                                                 4.021843
# energetic_gap_hs_eV                                                 4.552465
# Name: 20, dtype: object
# co 2 hydrogenisocyanide
# name                       co_2_methanol_methanol_methanol_hydrogenisocya...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            -6.927623
# energetic_homo_ls_eV                                              -14.432919
# energetic_homo_hs_eV                                              -14.944493
# energetic_lumo_ls_eV                                              -10.155289
# energetic_lumo_hs_eV                                              -10.351211
# energetic_gap_ls_eV                                                  4.27763
# energetic_gap_hs_eV                                                 4.593282
# Name: 21, dtype: object
# co 2 methanol
# name                       co_2_methanol_methanol_methanol_methanol_hydro...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                            -9.844729
# energetic_homo_ls_eV                                               -14.62612
# energetic_homo_hs_eV                                              -14.933609
# energetic_lumo_ls_eV                                               -10.13352
# energetic_lumo_hs_eV                                              -10.125357
# energetic_gap_ls_eV                                                   4.4926
# energetic_gap_hs_eV                                                 4.808252
# Name: 22, dtype: object
# co 2 methanol
# name                       co_2_methanol_methanol_methanol_methanol_metha...
# metal                                                                     co
# ox                                                                         2
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -11.825229
# energetic_homo_ls_eV                                              -14.691427
# energetic_homo_hs_eV                                               -14.96082
# energetic_lumo_ls_eV                                              -10.160732
# energetic_lumo_hs_eV                                              -10.193385
# energetic_gap_ls_eV                                                 4.530696
# energetic_gap_hs_eV                                                 4.767435
# Name: 23, dtype: object
# co 2 methanol
# name                       co_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            16.263849
# energetic_homo_ls_eV                                              -20.348674
# energetic_homo_hs_eV                                              -20.370444
# energetic_lumo_ls_eV                                              -16.185332
# energetic_lumo_hs_eV                                              -18.626194
# energetic_gap_ls_eV                                                 4.163342
# energetic_gap_hs_eV                                                  1.74425
# Name: 24, dtype: object
# co 3 hydrogencyanide
# name                       co_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            10.528242
# energetic_homo_ls_eV                                              -20.215339
# energetic_homo_hs_eV                                              -19.352738
# energetic_lumo_ls_eV                                              -16.196217
# energetic_lumo_hs_eV                                              -18.305099
# energetic_gap_ls_eV                                                 4.019122
# energetic_gap_hs_eV                                                 1.047638
# Name: 25, dtype: object
# co 3 hydrogencyanide
# name                       co_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            12.530986
# energetic_homo_ls_eV                                              -20.392213
# energetic_homo_hs_eV                                              -19.725534
# energetic_lumo_ls_eV                                              -16.141794
# energetic_lumo_hs_eV                                              -18.400339
# energetic_gap_ls_eV                                                 4.250418
# energetic_gap_hs_eV                                                 1.325194
# Name: 26, dtype: object
# co 3 hydrogencyanide
# name                       co_3_methanol_methanol_hydrogencyanide_hydroge...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            10.551125
# energetic_homo_ls_eV                                              -20.234387
# energetic_homo_hs_eV                                              -19.741861
# energetic_lumo_ls_eV                                              -16.054718
# energetic_lumo_hs_eV                                              -18.076524
# energetic_gap_ls_eV                                                 4.179669
# energetic_gap_hs_eV                                                 1.665337
# Name: 27, dtype: object
# co 3 methanol
# name                       co_3_methanol_methanol_methanol_hydrogencyanid...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                             8.102534
# energetic_homo_ls_eV                                              -20.226223
# energetic_homo_hs_eV                                              -19.491516
# energetic_lumo_ls_eV                                              -16.114583
# energetic_lumo_hs_eV                                               -18.11462
# energetic_gap_ls_eV                                                  4.11164
# energetic_gap_hs_eV                                                 1.376896
# Name: 28, dtype: object
# co 3 methanol
# name                       co_3_methanol_methanol_methanol_hydrogencyanid...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                             8.015672
# energetic_homo_ls_eV                                              -20.316021
# energetic_homo_hs_eV                                              -19.584035
# energetic_lumo_ls_eV                                              -16.051997
# energetic_lumo_hs_eV                                              -17.883323
# energetic_gap_ls_eV                                                 4.264024
# energetic_gap_hs_eV                                                 1.700712
# Name: 29, dtype: object
# co 3 methanol
# name                       co_3_methanol_methanol_methanol_methanol_hydro...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                             2.563264
# energetic_homo_ls_eV                                              -20.158195
# energetic_homo_hs_eV                                                -19.5024
# energetic_lumo_ls_eV                                              -16.125467
# energetic_lumo_hs_eV                                              -17.918698
# energetic_gap_ls_eV                                                 4.032727
# energetic_gap_hs_eV                                                 1.583703
# Name: 30, dtype: object
# co 3 methanol
# name                       co_3_methanol_methanol_methanol_methanol_metha...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                             6.264076
# energetic_homo_ls_eV                                              -20.356838
# energetic_homo_hs_eV                                               -19.59764
# energetic_lumo_ls_eV                                              -16.109141
# energetic_lumo_hs_eV                                              -17.611209
# energetic_gap_ls_eV                                                 4.247697
# energetic_gap_hs_eV                                                 1.986431
# Name: 31, dtype: object
# co 3 methanol
# name                       co_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            33.489888
# energetic_homo_ls_eV                                              -21.744619
# energetic_homo_hs_eV                                              -21.407197
# energetic_lumo_ls_eV                                              -15.937709
# energetic_lumo_hs_eV                                               -18.37857
# energetic_gap_ls_eV                                                  5.80691
# energetic_gap_hs_eV                                                 3.028627
# Name: 32, dtype: object
# co 3 hydrogencyanide
# name                       co_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            42.380244
# energetic_homo_ls_eV                                              -21.671148
# energetic_homo_hs_eV                                              -21.238487
# energetic_lumo_ls_eV                                              -15.826142
# energetic_lumo_hs_eV                                              -18.207138
# energetic_gap_ls_eV                                                 5.845006
# energetic_gap_hs_eV                                                 3.031348
# Name: 33, dtype: object
# co 3 hydrogencyanide
# name                       co_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            40.838493
# energetic_homo_ls_eV                                              -21.665706
# energetic_homo_hs_eV                                              -21.135084
# energetic_lumo_ls_eV                                              -15.695527
# energetic_lumo_hs_eV                                              -18.275167
# energetic_gap_ls_eV                                                 5.970178
# energetic_gap_hs_eV                                                 2.859917
# Name: 34, dtype: object
# co 3 hydrogencyanide
# name                       co_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            47.469182
# energetic_homo_ls_eV                                              -21.573187
# energetic_homo_hs_eV                                              -20.838479
# energetic_lumo_ls_eV                                              -15.573076
# energetic_lumo_hs_eV                                               -18.11462
# energetic_gap_ls_eV                                                 6.000111
# energetic_gap_hs_eV                                                  2.72386
# Name: 35, dtype: object
# co 3 hydrogencyanide
# name                       co_3_hydrogencyanide_hydrogencyanide_hydrogeni...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            48.799038
# energetic_homo_ls_eV                                              -21.635773
# energetic_homo_hs_eV                                              -21.015353
# energetic_lumo_ls_eV                                              -15.347222
# energetic_lumo_hs_eV                                              -18.190812
# energetic_gap_ls_eV                                                 6.288551
# energetic_gap_hs_eV                                                 2.824542
# Name: 36, dtype: object
# co 3 hydrogencyanide
# name                       co_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            55.780951
# energetic_homo_ls_eV                                              -21.554139
# energetic_homo_hs_eV                                              -20.574529
# energetic_lumo_ls_eV                                              -15.262866
# energetic_lumo_hs_eV                                              -18.106456
# energetic_gap_ls_eV                                                 6.291272
# energetic_gap_hs_eV                                                 2.468073
# Name: 37, dtype: object
# co 3 hydrogenisocyanide
# name                       co_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            57.000071
# energetic_homo_ls_eV                                              -21.643936
# energetic_homo_hs_eV                                              -20.593577
# energetic_lumo_ls_eV                                               -15.41525
# energetic_lumo_hs_eV                                              -18.081966
# energetic_gap_ls_eV                                                 6.228686
# energetic_gap_hs_eV                                                 2.511611
# Name: 38, dtype: object
# co 3 hydrogenisocyanide
# name                       co_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            63.799364
# energetic_homo_ls_eV                                              -21.589514
# energetic_homo_hs_eV                                              -20.424866
# energetic_lumo_ls_eV                                              -15.066944
# energetic_lumo_hs_eV                                              -18.016659
# energetic_gap_ls_eV                                                 6.522569
# energetic_gap_hs_eV                                                 2.408208
# Name: 39, dtype: object
# co 3 hydrogenisocyanide
# name                       co_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            53.065177
# energetic_homo_ls_eV                                              -19.994926
# energetic_homo_hs_eV                                              -20.179964
# energetic_lumo_ls_eV                                              -15.300962
# energetic_lumo_hs_eV                                              -17.866996
# energetic_gap_ls_eV                                                 4.693964
# energetic_gap_hs_eV                                                 2.312968
# Name: 40, dtype: object
# co 3 hydrogenisocyanide
# name                       co_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            35.950812
# energetic_homo_ls_eV                                              -20.190848
# energetic_homo_hs_eV                                              -19.369065
# energetic_lumo_ls_eV                                              -15.790767
# energetic_lumo_hs_eV                                              -17.905092
# energetic_gap_ls_eV                                                 4.400081
# energetic_gap_hs_eV                                                 1.463973
# Name: 41, dtype: object
# co 3 hydrogenisocyanide
# name                       co_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            38.766695
# energetic_homo_ls_eV                                              -19.926898
# energetic_homo_hs_eV                                              -20.076561
# energetic_lumo_ls_eV                                              -15.483279
# energetic_lumo_hs_eV                                              -17.679238
# energetic_gap_ls_eV                                                 4.443619
# energetic_gap_hs_eV                                                 2.397323
# Name: 42, dtype: object
# co 3 hydrogenisocyanide
# name                       co_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            25.485597
# energetic_homo_ls_eV                                              -20.139147
# energetic_homo_hs_eV                                              -19.456141
# energetic_lumo_ls_eV                                              -15.812536
# energetic_lumo_hs_eV                                              -17.837064
# energetic_gap_ls_eV                                                  4.32661
# energetic_gap_hs_eV                                                 1.619077
# Name: 43, dtype: object
# co 3 hydrogenisocyanide
# name                       co_3_hydrogenisocyanide_hydrogenisocyanide_met...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            30.534077
# energetic_homo_ls_eV                                              -20.030301
# energetic_homo_hs_eV                                              -19.665669
# energetic_lumo_ls_eV                                               -15.53498
# energetic_lumo_hs_eV                                              -17.532296
# energetic_gap_ls_eV                                                 4.495321
# energetic_gap_hs_eV                                                 2.133373
# Name: 44, dtype: object
# co 3 hydrogenisocyanide
# name                       co_3_methanol_methanol_methanol_hydrogenisocya...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            19.151348
# energetic_homo_ls_eV                                              -20.283367
# energetic_homo_hs_eV                                              -19.624852
# energetic_lumo_ls_eV                                              -15.839748
# energetic_lumo_hs_eV                                              -17.382633
# energetic_gap_ls_eV                                                 4.443619
# energetic_gap_hs_eV                                                 2.242218
# Name: 45, dtype: object
# co 3 methanol
# name                       co_3_methanol_methanol_methanol_methanol_hydro...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            11.260865
# energetic_homo_ls_eV                                              -20.130983
# energetic_homo_hs_eV                                                -19.5024
# energetic_lumo_ls_eV                                              -15.951314
# energetic_lumo_hs_eV                                              -17.521411
# energetic_gap_ls_eV                                                 4.179669
# energetic_gap_hs_eV                                                 1.980989
# Name: 46, dtype: object
# co 3 methanol
# name                       co_3_methanol_methanol_methanol_methanol_metha...
# metal                                                                     co
# ox                                                                         3
# high_spin                                                                  5
# spin_splitting_kcal/mol                                             8.292718
# energetic_homo_ls_eV                                              -20.340511
# energetic_homo_hs_eV                                              -19.475189
# energetic_lumo_ls_eV                                              -15.962199
# energetic_lumo_hs_eV                                              -17.521411
# energetic_gap_ls_eV                                                 4.378312
# energetic_gap_hs_eV                                                 1.953778
# Name: 47, dtype: object
# co 3 methanol
# name                       fe_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     fe
# ox                                                                         2
# high_spin                                                                  5
# spin_splitting_kcal/mol                                            -8.558689
# energetic_homo_ls_eV                                              -14.471015
# energetic_homo_hs_eV                                              -13.883249
# energetic_lumo_ls_eV                                               -8.587913
# energetic_lumo_hs_eV                                               -9.923992
# energetic_gap_ls_eV                                                 5.883102
# energetic_gap_hs_eV                                                 3.959257
# Name: 48, dtype: object
# fe 2 hydrogencyanide
# name                       fe_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     fe
# ox                                                                         2
# high_spin                                                                  5
# spin_splitting_kcal/mol                                           -14.177735
# energetic_homo_ls_eV                                              -14.285978
# energetic_homo_hs_eV                                              -13.891413
# energetic_lumo_ls_eV                                               -8.653221
# energetic_lumo_hs_eV                                               -9.681811
# energetic_gap_ls_eV                                                 5.632757
# energetic_gap_hs_eV                                                 4.209601
# Name: 49, dtype: object
# fe 2 hydrogencyanide
# name                       fe_2_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     fe
# ox                                                                         2
# high_spin                                                                  5
# spin_splitting_kcal/mol                                           -12.667151
# energetic_homo_ls_eV                                              -14.454688
# energetic_homo_hs_eV                                              -13.880528
# energetic_lumo_ls_eV                                               -8.587913
# energetic_lumo_hs_eV                                               -9.670927
# energetic_gap_ls_eV                                                 5.866775
# energetic_gap_hs_eV                                                 4.209601
# Name: 50, dtype: object
# fe 2 hydrogencyanide
# name                       fe_2_methanol_methanol_hydrogencyanide_hydroge...
# metal                                                                     fe
# ox                                                                         2
# high_spin                                                                  5
# spin_splitting_kcal/mol                                           -14.908415
# energetic_homo_ls_eV                                              -14.351285
# energetic_homo_hs_eV                                              -13.788009
# energetic_lumo_ls_eV                                               -8.544375
# energetic_lumo_hs_eV                                               -9.624667
# energetic_gap_ls_eV                                                  5.80691
# energetic_gap_hs_eV                                                 4.163342
# Name: 51, dtype: object
# fe 2 methanol
# name                       fe_2_methanol_methanol_methanol_hydrogencyanid...
# metal                                                                     fe
# ox                                                                         2
# high_spin                                                                  5
# spin_splitting_kcal/mol                                           -17.286365
# energetic_homo_ls_eV                                              -14.280535
# energetic_homo_hs_eV                                              -13.856038
# energetic_lumo_ls_eV                                               -8.571587
# energetic_lumo_hs_eV                                               -9.507658
# energetic_gap_ls_eV                                                 5.708949
# energetic_gap_hs_eV                                                 4.348379
# Name: 52, dtype: object
# fe 2 methanol
# name                       fe_2_methanol_methanol_methanol_hydrogencyanid...
# metal                                                                     fe
# ox                                                                         2
# high_spin                                                                  5
# spin_splitting_kcal/mol                                           -19.407046
# energetic_homo_ls_eV                                              -14.207065
# energetic_homo_hs_eV                                              -13.771682
# energetic_lumo_ls_eV                                               -8.492674
# energetic_lumo_hs_eV                                                -9.43963
# energetic_gap_ls_eV                                                 5.714391
# ...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -23.687619
# energetic_homo_ls_eV                                              -19.706486
# energetic_homo_hs_eV                                              -19.820774
# energetic_lumo_ls_eV                                              -15.692806
# energetic_lumo_hs_eV                                               -15.03157
# energetic_gap_ls_eV                                                 4.013679
# energetic_gap_hs_eV                                                 4.789204
# Name: 174, dtype: object
# cr 3 methanol
# name                       cr_3_methanol_methanol_methanol_methanol_metha...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -24.395352
# energetic_homo_ls_eV                                              -19.720091
# energetic_homo_hs_eV                                                -19.8371
# energetic_lumo_ls_eV                                              -15.665595
# energetic_lumo_hs_eV                                              -14.939051
# energetic_gap_ls_eV                                                 4.054497
# energetic_gap_hs_eV                                                 4.898049
# Name: 175, dtype: object
# cr 3 methanol
# name                       cr_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -24.351573
# energetic_homo_ls_eV                                              -20.487453
# energetic_homo_hs_eV                                              -21.192227
# energetic_lumo_ls_eV                                              -16.332274
# energetic_lumo_hs_eV                                              -15.352664
# energetic_gap_ls_eV                                                 4.155179
# energetic_gap_hs_eV                                                 5.839563
# Name: 176, dtype: object
# cr 3 hydrogencyanide
# name                       cr_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -20.201229
# energetic_homo_ls_eV                                              -20.479289
# energetic_homo_hs_eV                                               -21.15141
# energetic_lumo_ls_eV                                              -16.318668
# energetic_lumo_hs_eV                                              -15.358106
# energetic_gap_ls_eV                                                 4.160621
# energetic_gap_hs_eV                                                 5.793304
# Name: 177, dtype: object
# cr 3 hydrogencyanide
# name                       cr_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -24.399692
# energetic_homo_ls_eV                                              -20.424866
# energetic_homo_hs_eV                                              -21.165016
# energetic_lumo_ls_eV                                              -16.269688
# energetic_lumo_hs_eV                                               -15.36627
# energetic_gap_ls_eV                                                 4.155179
# energetic_gap_hs_eV                                                 5.798746
# Name: 178, dtype: object
# cr 3 hydrogencyanide
# name                       cr_3_hydrogencyanide_hydrogencyanide_hydrogenc...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -20.658473
# energetic_homo_ls_eV                                              -20.462962
# energetic_homo_hs_eV                                              -21.121478
# energetic_lumo_ls_eV                                               -16.34588
# energetic_lumo_hs_eV                                              -15.398923
# energetic_gap_ls_eV                                                 4.117083
# energetic_gap_hs_eV                                                 5.722554
# Name: 179, dtype: object
# cr 3 hydrogencyanide
# name                       cr_3_hydrogencyanide_hydrogencyanide_hydrogeni...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -24.243607
# energetic_homo_ls_eV                                              -20.392213
# energetic_homo_hs_eV                                              -21.124199
# energetic_lumo_ls_eV                                               -16.27513
# energetic_lumo_hs_eV                                              -15.317289
# energetic_gap_ls_eV                                                 4.117083
# energetic_gap_hs_eV                                                  5.80691
# Name: 180, dtype: object
# cr 3 hydrogencyanide
# name                       cr_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -24.134725
# energetic_homo_ls_eV                                              -20.403097
# energetic_homo_hs_eV                                              -21.099709
# energetic_lumo_ls_eV                                              -16.307784
# energetic_lumo_hs_eV                                              -15.360827
# energetic_gap_ls_eV                                                 4.095314
# energetic_gap_hs_eV                                                 5.738881
# Name: 181, dtype: object
# cr 3 hydrogenisocyanide
# name                       cr_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -24.289543
# energetic_homo_ls_eV                                              -20.373165
# energetic_homo_hs_eV                                              -21.129641
# energetic_lumo_ls_eV                                              -16.239755
# energetic_lumo_hs_eV                                              -15.466952
# energetic_gap_ls_eV                                                  4.13341
# energetic_gap_hs_eV                                                 5.662689
# Name: 182, dtype: object
# cr 3 hydrogenisocyanide
# name                       cr_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -26.388442
# energetic_homo_ls_eV                                               -20.45752
# energetic_homo_hs_eV                                              -21.132362
# energetic_lumo_ls_eV                                              -16.375812
# energetic_lumo_hs_eV                                              -15.428856
# energetic_gap_ls_eV                                                 4.081708
# energetic_gap_hs_eV                                                 5.703507
# Name: 183, dtype: object
# cr 3 hydrogenisocyanide
# name                       cr_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -23.286714
# energetic_homo_ls_eV                                              -19.755466
# energetic_homo_hs_eV                                              -19.714649
# energetic_lumo_ls_eV                                              -16.073766
# energetic_lumo_hs_eV                                              -15.409808
# energetic_gap_ls_eV                                                 3.681701
# energetic_gap_hs_eV                                                 4.304841
# Name: 184, dtype: object
# cr 3 hydrogenisocyanide
# name                       cr_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -22.000933
# energetic_homo_ls_eV                                              -19.711928
# energetic_homo_hs_eV                                              -19.613967
# energetic_lumo_ls_eV                                              -15.913219
# energetic_lumo_hs_eV                                              -15.450625
# energetic_gap_ls_eV                                                 3.798709
# energetic_gap_hs_eV                                                 4.163342
# Name: 185, dtype: object
# cr 3 hydrogenisocyanide
# name                       cr_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -23.868872
# energetic_homo_ls_eV                                              -19.654784
# energetic_homo_hs_eV                                               -19.66839
# energetic_lumo_ls_eV                                               -16.01118
# energetic_lumo_hs_eV                                              -15.203001
# energetic_gap_ls_eV                                                 3.643605
# energetic_gap_hs_eV                                                 4.465388
# Name: 186, dtype: object
# cr 3 hydrogenisocyanide
# name                       cr_3_hydrogenisocyanide_hydrogenisocyanide_hyd...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -23.420474
# energetic_homo_ls_eV                                              -19.347295
# energetic_homo_hs_eV                                              -19.605804
# energetic_lumo_ls_eV                                              -15.651989
# energetic_lumo_hs_eV                                              -15.238376
# energetic_gap_ls_eV                                                 3.695306
# energetic_gap_hs_eV                                                 4.367427
# Name: 187, dtype: object
# cr 3 hydrogenisocyanide
# name                       cr_3_hydrogenisocyanide_hydrogenisocyanide_met...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -23.950897
# energetic_homo_ls_eV                                               -19.71737
# energetic_homo_hs_eV                                              -19.820774
# energetic_lumo_ls_eV                                              -15.837027
# energetic_lumo_hs_eV                                              -14.979868
# energetic_gap_ls_eV                                                 3.880344
# energetic_gap_hs_eV                                                 4.840906
# Name: 188, dtype: object
# cr 3 hydrogenisocyanide
# name                       cr_3_methanol_methanol_methanol_hydrogenisocya...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -24.843071
# energetic_homo_ls_eV                                              -19.627573
# energetic_homo_hs_eV                                              -19.779957
# energetic_lumo_ls_eV                                              -15.856075
# energetic_lumo_hs_eV                                              -14.909118
# energetic_gap_ls_eV                                                 3.771498
# energetic_gap_hs_eV                                                 4.870838
# Name: 189, dtype: object
# cr 3 methanol
# name                       cr_3_methanol_methanol_methanol_methanol_hydro...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -23.528127
# energetic_homo_ls_eV                                              -19.635736
# energetic_homo_hs_eV                                                -19.8371
# energetic_lumo_ls_eV                                              -15.643826
# energetic_lumo_hs_eV                                              -14.871022
# energetic_gap_ls_eV                                                  3.99191
# energetic_gap_hs_eV                                                 4.966078
# Name: 190, dtype: object
# cr 3 methanol
# name                       cr_3_methanol_methanol_methanol_methanol_metha...
# metal                                                                     cr
# ox                                                                         3
# high_spin                                                                  4
# spin_splitting_kcal/mol                                           -24.674116
# energetic_homo_ls_eV                                              -19.646621
# energetic_homo_hs_eV                                              -19.823495
# energetic_lumo_ls_eV                                              -15.687364
# energetic_lumo_hs_eV                                              -14.887349
# energetic_gap_ls_eV                                                 3.959257
# energetic_gap_hs_eV                                                 4.936145
# Name: 191, dtype: object
# cr 3 methanol

# %%
df_raw = pd.read_csv(raw_data_path / "validation" / "validation_data_raw.csv")
df_train_val = pd.read_csv("/home/ralf/Dropbox (MIT)/many_body_expansion/data/training_data.csv")
for index, row in df_raw.iterrows():
    metal, ox, lig1, lig2, lig3, lig4, lig5, lig6 = row["name"].split("_")

    print(metal, ox, lig1)
    mask = (
        (df_train_val["metal"] == metal)
        & (df_train_val["ox"] == int(ox))
        & (df_train_val["lig1"] == lig1)
        & (df_train_val["lig2"] == lig2)
        & (df_train_val["lig3"] == lig3)
        & (df_train_val["lig4"] == lig4)
        & (df_train_val["lig5"] == lig5)
        & (df_train_val["lig6"] == lig6)
    )

    assert len(df_train_val[mask])  == 1
    # Write the two .xyz files
    entry = df_train_val[mask].iloc[0]
    with open(raw_data_path / "validation" / "xyzs" / f"{row['name']}_{entry['low_spin']}.xyz", "w") as fout:
        # Check if the first entry is a int:
        xyz_string = entry["xyz_ls"]
        try:
            n_atoms = int(xyz_string.split()[0])
            fout.write(xyz_string.replace("\t", "    "))
        except ValueError as m:
            n_atoms = len(xyz_string.split("\n")) - 1
            fout.write(f"{n_atoms}\n\n")
            fout.write(xyz_string.replace("\t", "    "))
    with open(raw_data_path / "validation" / "xyzs" / f"{row['name']}_{entry['high_spin']}.xyz", "w") as fout:
        xyz_string = entry["xyz_hs"]
        try:
            n_atoms = int(xyz_string.split()[0])
            fout.write(xyz_string.replace("\t", "    "))
        except ValueError as m:
            n_atoms = len(xyz_string.split("\n")) - 1
            fout.write(f"{n_atoms}\n\n")
            fout.write(xyz_string.replace("\t", "    "))
# Out:
# co 2 [SH]-[CH]=[CH]-[SH]
# cr 2 [OH]-[CH2]-[CH2]-[OH]
# cr 2 [PH2]-[CH2]-[CH2]-[PH2]
# cr 2 [S]=[CH]-[CH]=[S]
# cr 3 [PH2]-[S]-[S]-[PH2]
# fe 2 [OH]-[NH]-[NH]-[OH]
# fe 2 [O]=[CH]-[CH]=[O]
# fe 2 [SH]-[CH]=[CH]-[SH]
# fe 2 [SH]-[S]-[S]-[SH]
# fe 2 [S]=[CH]-[CH]=[S]
# fe 3 [OH]-[CH2]-[CH2]-[OH]
# mn 2 [OH]-[NH]-[NH]-[OH]
# mn 2 [SH]-[CH]=[CH]-[SH]
# mn 2 [SH]-[PH]-[PH]-[SH]
# mn 3 [PH2]-[CH2]-[CH2]-[PH2]
# co 2 [NH]=[CH]-[CH]=[NH]
# co 2 [OH]-[NH]-[NH]-[OH]
# co 2 [SH]-[NH]-[NH]-[SH]
# co 3 [NH]=[CH]-[CH]=[NH]
# cr 3 [NH2]-[PH]-[PH]-[NH2]
# cr 3 [NH2]-[S]-[S]-[NH2]
# cr 3 [NH]=[CH]-[CH]=[NH]
# fe 2 [NH]=[CH]-[CH]=[NH]
# co 2 [O+]-[PH3-]
# co 2 [O-]#[C+]
# co 2 [OH]-[OH]
# co 2 [OH]-[SH]
# co 2 formaldehyde
# co 2 phosphine
# co 2 [PH]=[CH2]
# co 2 [SH]-[CH3]
# co 3 [O+]-[PH3-]
# co 3 formaldehyde
# co 3 [O]=[PH]
# co 3 [PH]=[CH2]
# cr 2 [NH2]-[OH]
# cr 2 [NH]=[NH]
# cr 2 [N]#[N]
# cr 2 [OH]-[PH2]
# cr 2 formaldehyde
# cr 2 [PH]=[CH2]
# cr 3 [NH]=[NH]
# cr 3 [O+]-[NH3-]
# fe 2 [NH]=[NH]
# fe 2 [O+]-[NH3-]
# fe 2 formaldehyde
# fe 2 [O]=[PH]
# fe 2 [PH]=[CH2]
# fe 2 [SH]-[CH3]
# fe 2 [SH]-[NH2]
# fe 3 [C+]#[S-]
# fe 3 [CH+]=[PH2-]
# fe 3 [NH+]-[PH3-]
# fe 3 [NH]=[NH]
# fe 3 [O+]-[PH3-]
# fe 3 formaldehyde
# fe 3 [O]=[PH]
# fe 3 [PH2]-[OH]
# fe 3 [PH2]-[PH2]
# fe 3 [PH]=[CH2]
# mn 2 [NH2]-[OH]
# mn 2 [NH]=[NH]
# mn 2 [N]#[N]
# mn 2 [OH]-[PH2]
# mn 2 formaldehyde
# mn 2 [PH2]-[NH2]
# mn 2 [PH]=[CH2]
# mn 2 [SH]-[CH3]
# mn 3 [NH2]-[OH]
# mn 3 [NH]=[CH2]
# mn 3 [O+]-[SH2-]
# mn 3 formaldehyde
# mn 3 [O]=[PH]
# mn 3 [PH]=[CH2]
# cr 2 pisc
# mn 3 misc
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 pyr
# co 3 carbonyl
# co 3 misc
# co 3 misc
# co 3 misc
# co 3 misc
# co 3 water
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 misc
# cr 2 misc
# cr 2 pyr
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 furan
# cr 3 pyr
# cr 3 water
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 pyr
# fe 2 pyr
# fe 2 water
# fe 3 carbonyl
# fe 3 pyr
# fe 3 water
# mn 2 furan
# mn 2 misc
# mn 2 water
# mn 2 water
# mn 2 water
# mn 3 pyr
# mn 3 pyr
# co 2 formaldehyde
# co 2 formaldehyde
# co 2 formaldehyde
# co 2 formaldehyde
# co 2 formaldehyde
# co 2 acetonitrile
# co 2 water
# co 2 hydrogensulfide
# co 2 pyr
# co 2 pyr
# co 3 formaldehyde
# co 3 ammonia
# co 3 acetonitrile
# co 3 water
# cr 3 formaldehyde
# cr 3 formaldehyde
# cr 3 formaldehyde
# cr 3 formaldehyde
# cr 3 formaldehyde
# cr 3 formaldehyde
# cr 3 formaldehyde
# cr 3 ammonia
# cr 3 ammonia
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 N#C[O-]
# cr 3 N#C[O-]
# cr 3 cyanide
# cr 3 iodide
# cr 3 water
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# fe 2 formaldehyde
# fe 2 formaldehyde
# fe 2 formaldehyde
# fe 2 formaldehyde
# fe 2 formaldehyde
# fe 2 ammonia
# fe 2 water
# fe 2 water
# fe 2 hydrogensulfide
# fe 2 pyr
# fe 3 formaldehyde
# fe 3 formaldehyde
# fe 3 formaldehyde
# fe 3 formaldehyde
# fe 3 ammonia
# fe 3 acetonitrile
# fe 3 water
# fe 3 water
# fe 3 hydrogensulfide
# fe 3 hydrogensulfide
# fe 3 hydrogensulfide
# fe 3 pyr
# fe 3 pyr
# mn 2 formaldehyde
# mn 2 formaldehyde
# mn 2 formaldehyde
# mn 2 formaldehyde
# mn 2 formaldehyde
# mn 2 formaldehyde
# mn 2 formaldehyde
# mn 2 ammonia
# mn 2 ammonia
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 water
# mn 2 phosphine
# mn 2 hydrogensulfide
# fe 2 phosphine
# fe 2 phosphine
# fe 3 acetonitrile
# fe 3 phosphine
# fe 3 phosphine
# co 2 formaldehyde
# co 2 formaldehyde
# co 2 phosphine
# co 3 ammonia
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 carbonyl
# cr 2 formaldehyde
# cr 2 formaldehyde
# cr 2 formaldehyde
# cr 3 formaldehyde
# cr 3 formaldehyde
# cr 3 acetonitrile
# cr 3 cyanide
# fe 2 formaldehyde
# fe 2 ammonia
# fe 2 carbonyl
# fe 3 formaldehyde
# fe 3 formaldehyde
# fe 3 ammonia
# fe 3 acetonitrile
# fe 3 carbonyl
# fe 3 water
# mn 2 formaldehyde
# mn 2 hydrogensulfide
# mn 3 hydrogensulfide
# co 2 formaldehyde
# co 2 carbonyl
# co 3 formaldehyde
# cr 2 phosphine
# fe 2 carbonyl
# fe 2 pyr
# fe 3 carbonyl
# mn 2 formaldehyde
# mn 2 formaldehyde
# mn 2 formaldehyde
# mn 2 formaldehyde
# mn 2 ammonia
# mn 2 phosphine
# mn 3 formaldehyde
# mn 3 formaldehyde
# mn 3 formaldehyde
# co 2 hydrogensulfide
# co 2 pyr
# co 3 hydrogensulfide
# co 3 pyr
# co 3 pyr
# cr 2 formaldehyde
# cr 3 formaldehyde
# fe 2 carbonyl
# fe 3 acetonitrile
# fe 3 carbonyl
# mn 2 formaldehyde
# mn 2 water
# mn 2 pyr
# mn 3 formaldehyde
# mn 3 water
# mn 3 pyr
# co 2 formaldehyde
# co 2 formaldehyde
# co 2 hydrogensulfide
# co 3 formaldehyde
# fe 2 formaldehyde
# fe 2 phosphine
# fe 2 hydrogensulfide
# fe 2 pyr
# fe 3 formaldehyde
# fe 3 phosphine
# fe 3 phosphine
# fe 3 pyr
# mn 2 acetonitrile
# mn 3 acetonitrile
# co 2 ammonia
# fe 3 ammonia
# mn 2 ammonia
# mn 2 ammonia
# mn 3 ammonia
# mn 3 water
# cr 2 phosphine
# cr 2 phosphine
# cr 2 hydrogensulfide
# fe 3 phosphine
# mn 2 phosphine
# mn 2 phosphine
# mn 2 hydrogensulfide
# co 2 acetonitrile
# co 3 acetonitrile
# co 3 misc
# co 3 misc
# cr 2 misc
# cr 3 acetonitrile
# fe 2 acetonitrile
# fe 3 acetonitrile
# fe 3 misc
# fe 3 misc
# mn 2 acetonitrile
# mn 3 misc
# mn 3 misc
# co 2 ammonia
# co 2 water
# co 3 ammonia
# cr 2 water
# cr 3 ammonia
# fe 2 ammonia
# fe 2 carbonyl
# fe 2 water
# mn 2 ammonia
# mn 2 water
# mn 3 ammonia
# mn 3 water
# co 2 carbonyl
# co 2 carbonyl
# co 2 phosphine
# co 3 phosphine
# co 3 phosphine
# cr 3 cyanide
# cr 3 cyanide
# cr 3 hydrogensulfide
# fe 2 phosphine
# fe 3 carbonyl
# fe 3 phosphine
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# co 2 misc
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 misc
# cr 3 acetonitrile
# cr 3 misc
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 misc
# fe 3 acetonitrile
# fe 3 misc
# fe 3 misc
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 misc
# fe 2 acetonitrile
# co 3 carbonyl
# co 3 diazole
# fe 2 [CH+]=[OH-]
# fe 2 [N+]=[SH-]
# fe 2 [NH2]-[S]-[S]-[NH2]
# fe 2 ammonia
# fe 3 [NH2]-[S]-[S]-[NH2]
# fe 3 en
# fe 3 pisc
# mn 2 [NH2]-[SH]
# mn 2 [NH]=[CH]-[CH]=[NH]
# mn 2 carbonyl
# mn 2 diazole
# mn 3 [NH]=[CH]-[CH]=[NH]
# mn 3 formaldehyde
# cr 2 [NH]=[CH]-[CH]=[NH]
# cr 3 [O]=[PH]
# cr 3 [PH]=[CH2]

# %%
df_raw = pd.read_csv(raw_data_path / "training" / "training_data_raw.csv")
df_train_val = pd.read_csv("/home/ralf/Dropbox (MIT)/many_body_expansion/data/training_data.csv")
for index, row in df_raw.iterrows():
    metal, ox, lig1, lig2, lig3, lig4, lig5, lig6 = row["name"].split("_")

    print(metal, ox, lig1)
    mask = (
        (df_train_val["metal"] == metal)
        & (df_train_val["ox"] == int(ox))
        & (df_train_val["lig1"] == lig1)
        & (df_train_val["lig2"] == lig2)
        & (df_train_val["lig3"] == lig3)
        & (df_train_val["lig4"] == lig4)
        & (df_train_val["lig5"] == lig5)
        & (df_train_val["lig6"] == lig6)
    )

    assert len(df_train_val[mask])  == 1
    # Write the two .xyz files
    entry = df_train_val[mask].iloc[0]
    with open(raw_data_path / "training" / "xyzs" / f"{row['name']}_{entry['low_spin']}.xyz", "w") as fout:
        # Check if the first entry is a int:
        xyz_string = entry["xyz_ls"]
        try:
            n_atoms = int(xyz_string.split()[0])
            fout.write(xyz_string.replace("\t", "    "))
        except ValueError as m:
            n_atoms = len(xyz_string.split("\n")) - 1
            fout.write(f"{n_atoms}\n\n")
            fout.write(xyz_string.replace("\t", "    "))
    with open(raw_data_path / "training" / "xyzs" / f"{row['name']}_{entry['high_spin']}.xyz", "w") as fout:
        xyz_string = entry["xyz_hs"]
        try:
            n_atoms = int(xyz_string.split()[0])
            fout.write(xyz_string.replace("\t", "    "))
        except ValueError as m:
            n_atoms = len(xyz_string.split("\n")) - 1
            fout.write(f"{n_atoms}\n\n")
            fout.write(xyz_string.replace("\t", "    "))
# Out:
# co 2 [OH]-[PH]-[PH]-[OH]
# co 2 [OH]-[S]-[S]-[OH]
# co 2 [O]=[CH]-[CH]=[O]
# co 2 [PH2]-[CH]=[CH]-[PH2]
# co 2 [PH2]-[PH]-[PH]-[PH2]
# co 2 [PH2]-[S]-[S]-[PH2]
# co 2 [SH]-[CH2]-[CH2]-[SH]
# co 2 [SH]-[PH]-[PH]-[SH]
# co 2 [SH]-[S]-[S]-[SH]
# co 2 [S]=[CH]-[CH]=[S]
# co 3 [O]=[CH]-[CH]=[O]
# co 3 [S]=[CH]-[CH]=[S]
# cr 2 [OH]-[PH]-[PH]-[OH]
# cr 2 [OH]-[P]=[P]-[OH]
# cr 2 [PH2]-[CH]=[CH]-[PH2]
# cr 2 [PH2]-[O]-[O]-[PH2]
# cr 2 [PH2]-[PH]-[PH]-[PH2]
# cr 2 [SH]-[CH2]-[CH2]-[SH]
# cr 2 [SH]-[NH]-[NH]-[SH]
# cr 2 [SH]-[PH]-[PH]-[SH]
# cr 2 [SH]-[S]-[S]-[SH]
# cr 2 [S]=[P]-[P]=[S]
# cr 3 [NH]=[P]-[P]=[NH]
# cr 3 [OH]-[PH]-[PH]-[OH]
# cr 3 [O]=[CH]-[CH]=[O]
# cr 3 [PH2]-[O]-[O]-[PH2]
# fe 2 [OH]-[PH]-[PH]-[OH]
# fe 2 [OH]-[S]-[S]-[OH]
# fe 2 [PH2]-[S]-[S]-[PH2]
# fe 2 [SH]-[CH2]-[CH2]-[SH]
# fe 2 [SH]-[NH]-[NH]-[SH]
# fe 2 [SH]-[PH]-[PH]-[SH]
# fe 3 [O]=[CH]-[CH]=[O]
# fe 3 [PH2]-[CH]=[CH]-[PH2]
# fe 3 [S]=[CH]-[CH]=[S]
# mn 2 [OH]-[S]-[S]-[OH]
# mn 2 [O]=[CH]-[CH]=[O]
# mn 2 [PH2]-[PH]-[PH]-[PH2]
# mn 2 [PH2]-[S]-[S]-[PH2]
# mn 2 [SH]-[CH2]-[CH2]-[SH]
# mn 2 [SH]-[NH]-[NH]-[SH]
# mn 2 [SH]-[S]-[S]-[SH]
# mn 3 [SH]-[CH2]-[CH2]-[SH]
# mn 3 [S]=[CH]-[CH]=[S]
# co 2 [NH2]-[PH]-[PH]-[NH2]
# co 2 [OH]-[O]-[O]-[OH]
# co 2 [PH]=[P]-[P]=[PH]
# co 2 [S]-[NH]-[NH]-[S]
# co 3 [O]-[NH]-[NH]-[O]
# co 3 [PH2]-[S]-[S]-[PH2]
# co 3 [SH]-[CH2]-[CH2]-[SH]
# cr 2 [PH2]-[S]-[S]-[PH2]
# cr 3 [NH]=[N]-[N]=[NH]
# fe 2 [NH]=[P]-[P]=[NH]
# fe 2 [O]-[NH]-[NH]-[O]
# fe 2 [SH]-[O]-[O]-[SH]
# fe 2 [S]-[NH]-[NH]-[S]
# fe 3 [O]-[NH]-[NH]-[O]
# fe 3 [PH2]-[O]-[O]-[PH2]
# fe 3 [PH2]-[PH]-[PH]-[PH2]
# fe 3 [SH]-[CH2]-[CH2]-[SH]
# mn 2 [NH2]-[PH]-[PH]-[NH2]
# mn 3 [NH]=[P]-[P]=[NH]
# co 2 hydrogenisocyanide
# co 2 [C+]#[S-]
# co 2 methylamine
# co 2 [NH2]-[OH]
# co 2 [NH2]-[SH]
# co 2 [NH]=[CH2]
# co 2 hydrogencyanide
# co 2 [N]#[N]
# co 2 [N]#[P]
# co 2 methanol
# co 2 [OH]-[NH2]
# co 2 [OH]-[PH2]
# co 2 [PH2]-[CH3]
# co 2 [PH2]-[NH2]
# co 2 [PH2]-[PH2]
# co 2 [PH2]-[SH]
# co 2 [P]#[P]
# co 2 hydrogensulfide
# co 2 [SH]-[OH]
# co 3 hydrogenisocyanide
# co 3 [C+]#[S-]
# co 3 [N+]=[PH2-]
# co 3 [NH+]-[PH3-]
# co 3 methylamine
# co 3 [NH]=[CH2]
# co 3 [NH]=[PH]
# co 3 hydrogencyanide
# co 3 [N]#[N]
# co 3 [N]#[P]
# co 3 [O+]-[NH3-]
# co 3 [O+]-[SH2-]
# co 3 methanol
# co 3 [PH2]-[CH3]
# co 3 phosphine
# co 3 [P]#[P]
# cr 2 [C+]#[S-]
# cr 2 [NH]=[CH2]
# cr 2 [NH]=[PH]
# cr 2 hydrogencyanide
# cr 2 [N]#[P]
# cr 2 [O+]-[PH3-]
# cr 2 [O-]#[C+]
# cr 2 methanol
# cr 2 [OH]-[SH]
# cr 2 [PH+]-[PH3-]
# cr 2 phosphine
# cr 2 [PH]=[PH]
# cr 2 [P]#[P]
# cr 2 hydrogensulfide
# cr 3 hydrogenisocyanide
# cr 3 [NH+]-[NH3-]
# cr 3 hydrogencyanide
# cr 3 [N]#[N]
# cr 3 [O-]#[C+]
# cr 3 methanol
# cr 3 [OH]-[OH]
# cr 3 [OH]-[PH2]
# cr 3 [P]#[P]
# fe 2 hydrogenisocyanide
# fe 2 [C+]#[S-]
# fe 2 aminomethylene
# fe 2 [NH+]-[PH3-]
# fe 2 methylamine
# fe 2 [NH2]-[OH]
# fe 2 ammonia
# fe 2 hydrogencyanide
# fe 2 [N]#[N]
# fe 2 [N]#[P]
# fe 2 [O+]-[SH2-]
# fe 2 [O-]#[C+]
# fe 2 [OH]-[NH2]
# fe 2 [OH]-[OH]
# fe 2 [OH]-[PH2]
# fe 2 [OH]-[SH]
# fe 2 [PH+]-[PH3-]
# fe 2 [PH2]-[CH3]
# fe 2 [P]#[P]
# fe 2 [S+]-[NH3-]
# fe 2 [S-]#[C+]
# fe 2 hydrogensulfide
# fe 2 [SH]-[PH2]
# fe 2 [SH]-[SH]
# fe 2 [S]=[NH]
# fe 3 hydrogenisocyanide
# fe 3 [CH+]=[OH-]
# fe 3 [NH+]-[NH3-]
# fe 3 methylamine
# fe 3 [NH]=[CH2]
# fe 3 [NH]=[PH]
# fe 3 hydrogencyanide
# fe 3 [N]#[N]
# fe 3 [N]#[P]
# fe 3 methanol
# fe 3 [OH]-[SH]
# fe 3 [PH2]-[CH3]
# fe 3 [PH2]-[NH2]
# fe 3 phosphine
# fe 3 [PH]=[PH]
# mn 2 hydrogenisocyanide
# mn 2 [C+]#[S-]
# mn 2 methylamine
# mn 2 [NH2]-[PH2]
# mn 2 [NH]=[CH2]
# mn 2 [NH]=[PH]
# mn 2 hydrogencyanide
# mn 2 [N]#[P]
# mn 2 [O+]-[SH2-]
# mn 2 methanol
# mn 2 [OH]-[NH2]
# mn 2 [OH]-[SH]
# mn 2 [PH+]-[PH3-]
# mn 2 [PH2]-[CH3]
# mn 2 [PH2]-[OH]
# mn 2 [PH2]-[PH2]
# mn 2 [PH2]-[SH]
# mn 2 phosphine
# mn 2 [PH]=[NH]
# mn 2 [PH]=[PH]
# mn 2 [P]#[P]
# mn 2 hydrogensulfide
# mn 2 [SH]-[NH2]
# mn 2 [SH]-[OH]
# mn 2 [SH]-[PH2]
# mn 2 [SH]-[SH]
# mn 3 hydrogenisocyanide
# mn 3 [C+]#[S-]
# mn 3 [NH+]-[PH3-]
# mn 3 methylamine
# mn 3 [NH2]-[PH2]
# mn 3 [NH]=[PH]
# mn 3 hydrogencyanide
# mn 3 [N]#[N]
# mn 3 [N]#[P]
# mn 3 [O+]-[PH3-]
# mn 3 methanol
# mn 3 [PH2]-[CH3]
# mn 3 phosphine
# mn 3 [PH]=[PH]
# cr 2 bipy
# cr 2 misc
# cr 2 phen
# cr 3 acac
# cr 3 bipy
# cr 3 misc
# mn 2 acac
# mn 2 bipy
# mn 2 misc
# mn 2 phen
# mn 2 pisc
# mn 3 acac
# mn 3 bipy
# mn 3 phen
# co 3 porphyrin
# cr 2 phen
# fe 3 methylamine
# fe 3 phen
# mn 2 carbonyl
# mn 3 acac
# mn 3 carbonyl
# mn 3 ox
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 furan
# co 2 furan
# co 2 furan
# co 2 furan
# co 2 furan
# co 2 furan
# co 2 furan
# co 2 furan
# co 2 furan
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 pyr
# co 2 pyr
# co 2 pyr
# co 2 pyr
# co 2 pyr
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 3 carbonyl
# co 3 carbonyl
# co 3 carbonyl
# co 3 misc
# co 3 misc
# co 3 misc
# co 3 misc
# co 3 pyr
# co 3 pyr
# co 3 pyr
# co 3 pyr
# co 3 pyr
# co 3 pyr
# co 3 pyr
# co 3 pyr
# co 3 pyr
# co 3 water
# co 3 water
# co 3 water
# co 3 water
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 furan
# cr 2 misc
# cr 2 misc
# cr 2 misc
# cr 2 misc
# cr 2 misc
# cr 2 misc
# cr 2 misc
# cr 2 misc
# cr 2 pyr
# cr 2 pyr
# cr 2 pyr
# cr 2 pyr
# cr 2 pyr
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 furan
# cr 3 furan
# cr 3 furan
# cr 3 furan
# cr 3 furan
# cr 3 furan
# cr 3 furan
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 pyr
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 furan
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 furan
# fe 3 furan
# fe 3 furan
# fe 3 furan
# fe 3 furan
# fe 3 furan
# fe 3 furan
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 pyr
# fe 3 pyr
# fe 3 pyr
# fe 3 pyr
# fe 3 pyr
# fe 3 pyr
# fe 3 pyr
# fe 3 pyr
# fe 3 water
# fe 3 water
# fe 3 water
# fe 3 water
# fe 3 water
# fe 3 water
# fe 3 water
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 furan
# mn 2 furan
# mn 2 furan
# mn 2 furan
# mn 2 furan
# mn 2 furan
# mn 2 furan
# mn 2 furan
# mn 2 furan
# mn 2 furan
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 pyr
# mn 2 water
# mn 2 water
# mn 2 water
# mn 2 water
# mn 2 water
# mn 2 water
# mn 2 water
# mn 2 water
# mn 2 water
# mn 2 water
# mn 3 carbonyl
# mn 3 carbonyl
# mn 3 carbonyl
# mn 3 carbonyl
# mn 3 furan
# mn 3 furan
# mn 3 furan
# mn 3 misc
# mn 3 misc
# mn 3 misc
# mn 3 misc
# mn 3 misc
# mn 3 misc
# mn 3 misc
# mn 3 pyr
# mn 3 pyr
# mn 3 pyr
# mn 3 pyr
# mn 3 pyr
# mn 3 pyr
# mn 3 pyr
# mn 3 pyr
# mn 3 water
# mn 3 water
# mn 3 water
# mn 3 water
# mn 3 water
# mn 3 water
# co 2 ammonia
# co 2 ammonia
# co 2 ammonia
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 carbonyl
# co 2 carbonyl
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 2 phosphine
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# co 2 pyr
# co 2 pyr
# co 3 ammonia
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 cyanide
# co 3 carbonyl
# co 3 iodide
# co 3 iodide
# co 3 [OH-]
# co 3 water
# co 3 water
# co 3 hydrogensulfide
# co 3 pyr
# co 3 pyr
# co 3 pyr
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 N#C[O-]
# cr 3 cyanide
# cr 3 cyanide
# cr 3 cyanide
# cr 3 carbonyl
# cr 3 fluoride
# cr 3 fluoride
# cr 3 fluoride
# cr 3 iodide
# cr 3 iodide
# cr 3 iodide
# cr 3 iodide
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 phosphine
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# fe 2 ammonia
# fe 2 ammonia
# fe 2 ammonia
# fe 2 ammonia
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 phosphine
# fe 2 phosphine
# fe 2 hydrogensulfide
# fe 2 hydrogensulfide
# fe 2 hydrogensulfide
# fe 2 hydrogensulfide
# fe 2 hydrogensulfide
# fe 2 hydrogensulfide
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 2 pyr
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 cyanide
# fe 3 fluoride
# fe 3 iodide
# fe 3 [OH-]
# fe 3 water
# fe 3 water
# fe 3 water
# fe 3 phosphine
# fe 3 hydrogensulfide
# fe 3 hydrogensulfide
# fe 3 pyr
# fe 3 pyr
# fe 3 pyr
# fe 3 pyr
# mn 2 ammonia
# mn 2 ammonia
# mn 2 ammonia
# mn 2 ammonia
# mn 2 ammonia
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 water
# mn 2 water
# mn 2 water
# mn 2 water
# mn 2 phosphine
# mn 2 phosphine
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 2 pyr
# mn 2 pyr
# fe 2 phosphine
# fe 3 acetonitrile
# fe 3 fluoride
# fe 3 iodide
# fe 3 [OH-]
# fe 3 water
# mn 2 ammonia
# mn 2 water
# mn 2 phosphine
# mn 2 phosphine
# co 2 acetonitrile
# co 2 hydrogensulfide
# co 3 carbonyl
# co 3 phosphine
# mn 2 phosphine
# mn 2 phosphine
# co 2 water
# co 2 phosphine
# co 3 acetonitrile
# co 3 water
# co 3 phosphine
# cr 2 ammonia
# cr 3 ammonia
# fe 2 ammonia
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 carbonyl
# fe 2 hydrogensulfide
# fe 3 ammonia
# fe 3 acetonitrile
# fe 3 carbonyl
# mn 2 water
# mn 2 hydrogensulfide
# mn 2 pyr
# mn 3 hydrogensulfide
# mn 3 hydrogensulfide
# mn 3 pyr
# co 2 acetonitrile
# co 2 phosphine
# co 3 acetonitrile
# co 3 phosphine
# cr 2 hydrogensulfide
# cr 3 ammonia
# cr 3 ammonia
# cr 3 cyanide
# cr 3 iodide
# cr 3 water
# cr 3 phosphine
# cr 3 hydrogensulfide
# fe 2 ammonia
# fe 2 ammonia
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 hydrogensulfide
# fe 3 ammonia
# fe 3 ammonia
# fe 3 acetonitrile
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 phosphine
# fe 3 pyr
# mn 2 carbonyl
# mn 2 water
# mn 2 pyr
# mn 3 water
# co 2 ammonia
# co 2 ammonia
# co 2 ammonia
# co 2 phosphine
# co 2 hydrogensulfide
# co 3 ammonia
# co 3 ammonia
# co 3 ammonia
# co 3 phosphine
# cr 2 water
# cr 2 water
# cr 3 ammonia
# cr 3 cyanide
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 phosphine
# fe 2 acetonitrile
# fe 2 phosphine
# fe 2 phosphine
# fe 2 hydrogensulfide
# fe 2 pyr
# fe 3 phosphine
# fe 3 phosphine
# mn 2 acetonitrile
# mn 2 phosphine
# mn 2 phosphine
# mn 2 hydrogensulfide
# mn 2 pyr
# mn 3 ammonia
# mn 3 ammonia
# mn 3 acetonitrile
# mn 3 water
# mn 3 phosphine
# co 2 carbonyl
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# cr 2 pyr
# cr 3 ammonia
# cr 3 iodide
# cr 3 water
# fe 2 ammonia
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 carbonyl
# fe 2 phosphine
# fe 2 pyr
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 hydrogensulfide
# fe 3 pyr
# mn 2 water
# mn 3 water
# mn 3 pyr
# co 2 ammonia
# co 2 ammonia
# co 2 ammonia
# co 2 ammonia
# co 2 ammonia
# co 2 carbonyl
# co 2 water
# co 3 ammonia
# co 3 ammonia
# co 3 ammonia
# co 3 ammonia
# co 3 ammonia
# co 3 water
# co 3 water
# co 3 water
# cr 2 ammonia
# cr 2 ammonia
# cr 2 ammonia
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 water
# cr 2 water
# cr 2 water
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 carbonyl
# cr 3 fluoride
# cr 3 fluoride
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# fe 2 ammonia
# fe 2 ammonia
# fe 2 ammonia
# fe 2 ammonia
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 water
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 water
# fe 3 water
# fe 3 water
# mn 2 ammonia
# mn 2 carbonyl
# mn 3 ammonia
# mn 3 ammonia
# mn 3 ammonia
# mn 3 carbonyl
# mn 3 carbonyl
# mn 3 water
# mn 3 water
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 phosphine
# co 2 phosphine
# co 2 phosphine
# co 2 phosphine
# co 2 phosphine
# co 2 phosphine
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# co 3 carbonyl
# co 3 cyanide
# co 3 cyanide
# co 3 cyanide
# co 3 cyanide
# co 3 cyanide
# co 3 phosphine
# co 3 phosphine
# co 3 phosphine
# co 3 phosphine
# co 3 phosphine
# co 3 hydrogensulfide
# co 3 hydrogensulfide
# cr 2 carbonyl
# cr 2 phosphine
# cr 2 phosphine
# cr 2 phosphine
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 cyanide
# cr 3 cyanide
# cr 3 cyanide
# cr 3 cyanide
# cr 3 phosphine
# cr 3 phosphine
# cr 3 phosphine
# cr 3 phosphine
# cr 3 phosphine
# cr 3 phosphine
# cr 3 phosphine
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 phosphine
# fe 2 phosphine
# fe 2 phosphine
# fe 2 hydrogensulfide
# fe 2 hydrogensulfide
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 cyanide
# fe 3 cyanide
# fe 3 cyanide
# fe 3 phosphine
# fe 3 phosphine
# fe 3 phosphine
# fe 3 hydrogensulfide
# fe 3 hydrogensulfide
# mn 2 carbonyl
# mn 2 phosphine
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 3 carbonyl
# mn 3 cyanide
# mn 3 cyanide
# mn 3 cyanide
# mn 3 phosphine
# mn 3 phosphine
# mn 3 phosphine
# mn 3 hydrogensulfide
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 phosphine
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 chloride
# co 3 chloride
# co 3 chloride
# co 3 chloride
# co 3 chloride
# co 3 misc
# co 3 misc
# co 3 phosphine
# cr 2 acetonitrile
# cr 2 acetonitrile
# cr 2 acetonitrile
# cr 2 acetonitrile
# cr 2 misc
# cr 2 misc
# cr 2 misc
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 chloride
# cr 3 chloride
# cr 3 chloride
# cr 3 chloride
# cr 3 chloride
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 phosphine
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 chloride
# fe 3 chloride
# fe 3 chloride
# fe 3 chloride
# fe 3 chloride
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 phosphine
# mn 2 acetonitrile
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 chloride
# mn 3 chloride
# mn 3 chloride
# mn 3 chloride
# mn 3 chloride
# mn 3 misc
# mn 3 misc
# mn 3 misc
# mn 3 misc
# mn 3 misc
# co 3 phosphine
# mn 3 chloride
# co 2 ammonia
# co 2 ammonia
# co 2 ammonia
# co 2 ammonia
# co 2 carbonyl
# co 2 carbonyl
# co 2 carbonyl
# co 2 water
# co 2 water
# co 2 water
# co 2 water
# co 3 ammonia
# co 3 ammonia
# co 3 ammonia
# co 3 ammonia
# co 3 ammonia
# co 3 water
# co 3 water
# co 3 water
# cr 2 ammonia
# cr 2 ammonia
# cr 2 ammonia
# cr 2 ammonia
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 carbonyl
# cr 2 water
# cr 2 water
# cr 2 water
# cr 2 water
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 ammonia
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# cr 3 water
# fe 2 ammonia
# fe 2 ammonia
# fe 2 ammonia
# fe 2 ammonia
# fe 2 ammonia
# fe 2 ammonia
# fe 2 carbonyl
# fe 2 water
# fe 2 water
# fe 2 water
# fe 2 water
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 ammonia
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 carbonyl
# fe 3 water
# fe 3 water
# fe 3 water
# fe 3 water
# fe 3 water
# mn 2 ammonia
# mn 2 ammonia
# mn 2 ammonia
# mn 2 ammonia
# mn 2 ammonia
# mn 2 ammonia
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 water
# mn 2 water
# mn 3 ammonia
# mn 3 ammonia
# mn 3 ammonia
# mn 3 ammonia
# mn 3 ammonia
# mn 3 ammonia
# mn 3 ammonia
# mn 3 ammonia
# mn 3 carbonyl
# mn 3 carbonyl
# mn 3 water
# mn 3 water
# mn 3 water
# mn 3 water
# co 2 carbonyl
# co 2 carbonyl
# co 2 phosphine
# co 2 phosphine
# co 2 phosphine
# co 2 phosphine
# co 2 phosphine
# co 2 phosphine
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# co 2 hydrogensulfide
# co 3 carbonyl
# co 3 phosphine
# co 3 phosphine
# co 3 phosphine
# co 3 phosphine
# cr 2 carbonyl
# cr 2 phosphine
# cr 2 phosphine
# cr 2 phosphine
# cr 2 phosphine
# cr 2 phosphine
# cr 2 phosphine
# cr 2 phosphine
# cr 2 phosphine
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 2 hydrogensulfide
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 carbonyl
# cr 3 cyanide
# cr 3 cyanide
# cr 3 cyanide
# cr 3 phosphine
# cr 3 phosphine
# cr 3 phosphine
# cr 3 phosphine
# cr 3 phosphine
# cr 3 phosphine
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# cr 3 hydrogensulfide
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 carbonyl
# fe 2 phosphine
# fe 2 phosphine
# fe 2 phosphine
# fe 2 phosphine
# fe 2 phosphine
# fe 2 hydrogensulfide
# fe 2 hydrogensulfide
# fe 3 carbonyl
# fe 3 phosphine
# fe 3 phosphine
# fe 3 phosphine
# fe 3 phosphine
# fe 3 phosphine
# fe 3 phosphine
# fe 3 hydrogensulfide
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 carbonyl
# mn 2 phosphine
# mn 2 phosphine
# mn 2 phosphine
# mn 2 phosphine
# mn 2 phosphine
# mn 2 phosphine
# mn 2 phosphine
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 2 hydrogensulfide
# mn 3 carbonyl
# mn 3 carbonyl
# mn 3 phosphine
# mn 3 phosphine
# mn 3 phosphine
# mn 3 phosphine
# mn 3 phosphine
# mn 3 hydrogensulfide
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 acetonitrile
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 misc
# co 2 phosphine
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 acetonitrile
# co 3 misc
# co 3 misc
# co 3 misc
# co 3 phosphine
# cr 2 acetonitrile
# cr 2 acetonitrile
# cr 2 acetonitrile
# cr 2 misc
# cr 2 misc
# cr 2 misc
# cr 2 misc
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 acetonitrile
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# cr 3 misc
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 acetonitrile
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 misc
# fe 2 phosphine
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 acetonitrile
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 misc
# fe 3 phosphine
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 acetonitrile
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 2 misc
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 acetonitrile
# mn 3 misc
# mn 3 misc
# mn 3 misc
# mn 3 misc
# mn 3 misc
# cr 3 acetonitrile
# cr 3 phosphine
# cr 3 hydrogensulfide
# cr 2 acetonitrile
# fe 3 acetonitrile
# mn 3 chloride
# co 2 [N+]=[SH-]
# co 2 [NH2]-[NH2]
# co 2 [NH2]-[PH2]
# co 2 [PH]=[NH]
# co 2 [N+]=[NH2-]
# co 2 [NH]=[N]-[N]=[NH]
# co 2 aminomethylene
# co 2 ammonia
# co 2 carbonyl
# co 2 diazole
# co 2 imidazolidinone
# co 2 phosphorine
# co 2 water
# co 3 aminomethylene
# co 3 ammonia
# co 3 en
# co 3 imidazolidinone
# co 3 phosphorine
# co 3 water
# fe 2 [N+]=[NH2-]
# fe 2 [N+]=[PH2-]
# fe 2 [NH2]-[NH2]
# fe 2 [NH2]-[SH]
# fe 2 [O]-[S]-[S]-[O]
# fe 2 [PH]=[NH]
# fe 2 [SH]-[OH]
# fe 2 carbonyl
# fe 2 diazole
# fe 2 en
# fe 2 imidazolidinone
# fe 2 methanol
# fe 2 phosphorine
# fe 2 pisc
# fe 2 water
# fe 3 [N+]=[PH2-]
# fe 3 [N+]=[SH-]
# fe 3 [NH2]-[NH2]
# fe 3 [NH2]-[PH2]
# fe 3 [NH2]-[SH]
# fe 3 [O]-[S]-[S]-[O]
# fe 3 [PH]=[NH]
# fe 3 aminomethylene
# fe 3 ammonia
# fe 3 carbonyl
# fe 3 imidazolidinone
# fe 3 phosphorine
# fe 3 water
# mn 2 [S+]-[NH3-]
# mn 2 [PH]=[P]-[P]=[PH]
# mn 2 ammonia
# mn 2 imidazolidinone
# mn 2 phosphorine
# mn 2 water
# mn 3 aminomethylene
# mn 3 ammonia
# mn 3 carbonyl
# mn 3 diazole
# mn 3 imidazolidinone
# mn 3 phosphorine
# mn 3 water
# mn 3 water
# cr 2 ammonia
# cr 2 carbonyl
# cr 2 diazole
# cr 2 hydrogenisocyanide
# cr 2 imidazolidinone
# cr 2 phosphorine
# cr 2 water
# cr 3 [CH+]=[PH2-]
# cr 3 [N+]=[PH2-]
# cr 3 [NH]=[PH]
# cr 3 [SH]-[O]-[O]-[SH]
# cr 3 aminomethylene
# cr 3 ammonia
# cr 3 carbonyl
# cr 3 diazole
# cr 3 hydrogensulfide
# cr 3 imidazolidinone
# cr 3 phosphine
# cr 3 phosphorine
# cr 3 water
# cr 3 water
